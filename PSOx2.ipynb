# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtalas/SezgiselOtimizasyonDersNotlari/blob/main/PSOx2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PSO x^2 Örneği
#
#
# Parçacık Sürü Optimizasyon algortimasının x^2 maliyet  fonksiyonu ile çalışma örneği yapılmıştır.
#
# Örnek üzerinde parametreler değiştirilerek sonuçlar gözlemlenebilir.

# %%
import numpy as np

# Optimize etmek istediğimiz fonksiyon: f(x) = x^2
def cost_function(x):
    return x ** 2

# PSO parametreleri
w = 0.5  # Eylemsizlik katsayısı
c1 = 1.2  # Bireysel öğrenme katsayısı (cognitive component)
c2 = 1.5  # Sosyal öğrenme katsayısı (social component)
n_particles = 10  # Parçacık sayısı
n_iterations = 10  # İterasyon sayısı
dimension = 1  # Tek boyutlu problem (x)

# Parçacıkların başlangıç pozisyonları ve hızları
particles_pos = np.random.uniform(-10, 10, (n_particles, dimension))  # [-10, 10] aralığında rastgele başlat
particles_vel = np.random.uniform(-1, 1, (n_particles, dimension))    # Başlangıç hızları [-1, 1] aralığında

# Her parçacık için en iyi pozisyon (pbest) ve en iyi değerler
pbest_pos = np.copy(particles_pos)
pbest_val = np.array([cost_function(p) for p in pbest_pos])

# Global en iyi pozisyon ve değeri (gbest)
gbest_pos = pbest_pos[np.argmin(pbest_val)]
gbest_val = np.min(pbest_val)

# PSO algoritması
for iteration in range(n_iterations):
    print(f"--- Iterasyon {iteration + 1} ---")

    # Her parçacık için hız ve pozisyon güncellemeleri
    for i in range(n_particles):
        r1, r2 = np.random.rand(2)  # Rastgele sayılar

        # Hız güncellemesi (velocity update)
        particles_vel[i] = (w * particles_vel[i] +
                            c1 * r1 * (pbest_pos[i] - particles_pos[i]) +
                            c2 * r2 * (gbest_pos - particles_pos[i]))

        # Pozisyon güncellemesi (position update)

        particles_pos[i] =  particles_pos[i] + particles_vel[i]

        # Bu pozisyondaki değeri hesapla
        fitness_value = cost_function(particles_pos[i])

        # pbest güncellemesi
        if fitness_value < pbest_val[i]:
            pbest_pos[i] = particles_pos[i]
            pbest_val[i] = fitness_value

        # gbest güncellemesi
        if fitness_value < gbest_val:
            gbest_pos = particles_pos[i]
            gbest_val = fitness_value

        # Parçacık bilgilerini yazdır
        print(f"Parçacık {i+1}: Pozisyon = {particles_pos[i][0]:.4f}, Hız = {particles_vel[i][0]:.4f}, Maliyet/Fitness = {fitness_value[0]:.4f}")

    # pbest ve gbest bilgilerini yazdır
    print(f"pbest: {[round(val[0], 4) for val in pbest_val]}")
    print(f"gbest: {gbest_val[0]:.4f}\n")

print(f"Global Best Pozisyon: {gbest_pos}")
print(f"Global Best : {gbest_val}")
# Out:
# --- Iterasyon 1 ---
# Parçacık 1: Pozisyon = -0.9607, Hız = 0.3681, Maliyet/Fitness = 0.9230
# Parçacık 2: Pozisyon = -1.0633, Hız = 1.5587, Maliyet/Fitness = 1.1307
# Parçacık 3: Pozisyon = -0.3060, Hız = -6.6138, Maliyet/Fitness = 0.0936
# Parçacık 4: Pozisyon = 6.3235, Hız = -0.6057, Maliyet/Fitness = 39.9865
# Parçacık 5: Pozisyon = -3.8724, Hız = 2.5994, Maliyet/Fitness = 14.9958
# Parçacık 6: Pozisyon = -0.6593, Hız = -1.4162, Maliyet/Fitness = 0.4346
# Parçacık 7: Pozisyon = -0.2836, Hız = 4.9398, Maliyet/Fitness = 0.0804
# Parçacık 8: Pozisyon = 2.5547, Hız = 12.3767, Maliyet/Fitness = 6.5267
# Parçacık 9: Pozisyon = 1.6178, Hız = -1.7000, Maliyet/Fitness = 2.6173
# Parçacık 10: Pozisyon = -0.1659, Hız = 1.7315, Maliyet/Fitness = 0.0275
# pbest: [0.923, 1.1307, 0.0936, 39.9865, 14.9958, 0.4346, 0.0804, 6.5267, 2.6173, 0.0275]
# gbest: 0.0275
#
# --- Iterasyon 2 ---
# Parçacık 1: Pozisyon = -0.7446, Hız = 0.2162, Maliyet/Fitness = 0.5544
# Parçacık 2: Pozisyon = 0.1838, Hız = 1.2471, Maliyet/Fitness = 0.0338
# Parçacık 3: Pozisyon = -3.5913, Hız = -3.2853, Maliyet/Fitness = 12.8972
# Parçacık 4: Pozisyon = 2.1848, Hız = -4.1387, Maliyet/Fitness = 4.7732
# Parçacık 5: Pozisyon = -0.2487, Hız = 3.6238, Maliyet/Fitness = 0.0618
# Parçacık 6: Pozisyon = -0.8350, Hız = -0.1757, Maliyet/Fitness = 0.6972
# Parçacık 7: Pozisyon = 2.2699, Hız = 2.5535, Maliyet/Fitness = 5.1525
# Parçacık 8: Pozisyon = 8.2188, Hız = 5.6640, Maliyet/Fitness = 67.5483
# Parçacık 9: Pozisyon = 0.0995, Hız = -1.5183, Maliyet/Fitness = 0.0099
# Parçacık 10: Pozisyon = 0.8049, Hız = 0.9709, Maliyet/Fitness = 0.6479
# pbest: [0.5544, 0.0338, 0.0936, 4.7732, 0.0618, 0.4346, 0.0804, 6.5267, 0.0099, 0.0275]
# gbest: 0.0099
#
# --- Iterasyon 3 ---
# Parçacık 1: Pozisyon = -0.0210, Hız = 0.7235, Maliyet/Fitness = 0.0004
# Parçacık 2: Pozisyon = 0.6658, Hız = 0.4820, Maliyet/Fitness = 0.4433
# Parçacık 3: Pozisyon = 1.6019, Hız = 5.1931, Maliyet/Fitness = 2.5659
# Parçacık 4: Pozisyon = -2.6855, Hız = -4.8703, Maliyet/Fitness = 7.2118
# Parçacık 5: Pozisyon = 1.8606, Hız = 2.1093, Maliyet/Fitness = 3.4619
# Parçacık 6: Pozisyon = -0.6585, Hız = 0.1765, Maliyet/Fitness = 0.4336
# Parçacık 7: Pozisyon = -1.4004, Hız = -3.6703, Maliyet/Fitness = 1.9611
# Parçacık 8: Pozisyon = 0.3025, Hız = -7.9163, Maliyet/Fitness = 0.0915
# Parçacık 9: Pozisyon = -0.6763, Hız = -0.7758, Maliyet/Fitness = 0.4574
# Parçacık 10: Pozisyon = 0.3255, Hız = -0.4794, Maliyet/Fitness = 0.1060
# pbest: [0.0004, 0.0338, 0.0936, 4.7732, 0.0618, 0.4336, 0.0804, 0.0915, 0.0099, 0.0275]
# gbest: 0.0004
#
# --- Iterasyon 4 ---
# Parçacık 1: Pozisyon = 0.3408, Hız = 0.3618, Maliyet/Fitness = 0.1161
# Parçacık 2: Pozisyon = 0.5648, Hız = -0.1010, Maliyet/Fitness = 0.3190
# Parçacık 3: Pozisyon = 2.2738, Hız = 0.6719, Maliyet/Fitness = 5.1700
# Parçacık 4: Pozisyon = 2.4741, Hız = 5.1596, Maliyet/Fitness = 6.1213
# Parçacık 5: Pozisyon = 2.1601, Hız = 0.2995, Maliyet/Fitness = 4.6662
# Parçacık 6: Pozisyon = -0.2207, Hız = 0.4378, Maliyet/Fitness = 0.0487
# Parçacık 7: Pozisyon = -0.9873, Hız = 0.4131, Maliyet/Fitness = 0.9747
# Parçacık 8: Pozisyon = -3.6292, Hız = -3.9316, Maliyet/Fitness = 13.1708
# Parçacık 9: Pozisyon = 0.0057, Hız = 0.6820, Maliyet/Fitness = 0.0000
# Parçacık 10: Pozisyon = -0.6757, Hız = -1.0013, Maliyet/Fitness = 0.4566
# pbest: [0.0004, 0.0338, 0.0936, 4.7732, 0.0618, 0.0487, 0.0804, 0.0915, 0.0, 0.0275]
# gbest: 0.0000
#
# --- Iterasyon 5 ---
# Parçacık 1: Pozisyon = 0.3607, Hız = 0.0199, Maliyet/Fitness = 0.1301
# Parçacık 2: Pozisyon = -0.1987, Hız = -0.7635, Maliyet/Fitness = 0.0395
# Parçacık 3: Pozisyon = 1.4011, Hız = -0.8726, Maliyet/Fitness = 1.9632
# Parçacık 4: Pozisyon = 1.3529, Hız = -1.1212, Maliyet/Fitness = 1.8303
# Parçacık 5: Pozisyon = 0.7186, Hız = -1.4416, Maliyet/Fitness = 0.5163
# Parçacık 6: Pozisyon = 0.2160, Hız = 0.4367, Maliyet/Fitness = 0.0467
# Parçacık 7: Pozisyon = 1.1847, Hız = 2.1720, Maliyet/Fitness = 1.4035
# Parçacık 8: Pozisyon = -1.7657, Hız = 1.8634, Maliyet/Fitness = 3.1178
# Parçacık 9: Pozisyon = 0.3467, Hız = 0.3410, Maliyet/Fitness = 0.1202
# Parçacık 10: Pozisyon = 0.8696, Hız = 1.5454, Maliyet/Fitness = 0.7563
# pbest: [0.0004, 0.0338, 0.0936, 1.8303, 0.0618, 0.0467, 0.0804, 0.0915, 0.0, 0.0275]
# gbest: 0.0000
#
# --- Iterasyon 6 ---
# Parçacık 1: Pozisyon = 0.3100, Hız = -0.0507, Maliyet/Fitness = 0.0961
# Parçacık 2: Pozisyon = -0.2673, Hız = -0.0687, Maliyet/Fitness = 0.0715
# Parçacık 3: Pozisyon = -1.3897, Hız = -2.7908, Maliyet/Fitness = 1.9312
# Parçacık 4: Pozisyon = 0.5334, Hız = -0.8195, Maliyet/Fitness = 0.2845
# Parçacık 5: Pozisyon = -0.2788, Hız = -0.9973, Maliyet/Fitness = 0.0777
# Parçacık 6: Pozisyon = 0.4797, Hız = 0.2636, Maliyet/Fitness = 0.2301
# Parçacık 7: Pozisyon = 0.6127, Hız = -0.5720, Maliyet/Fitness = 0.3754
# Parçacık 8: Pozisyon = 2.2609, Hız = 4.0266, Maliyet/Fitness = 5.1115
# Parçacık 9: Pozisyon = 0.1662, Hız = -0.1805, Maliyet/Fitness = 0.0276
# Parçacık 10: Pozisyon = -0.0346, Hız = -0.9042, Maliyet/Fitness = 0.0012
# pbest: [0.0004, 0.0338, 0.0936, 0.2845, 0.0618, 0.0467, 0.0804, 0.0915, 0.0, 0.0012]
# gbest: 0.0000
#
# --- Iterasyon 7 ---
# Parçacık 1: Pozisyon = -0.1605, Hız = -0.4705, Maliyet/Fitness = 0.0258
# Parçacık 2: Pozisyon = 0.4216, Hız = 0.6889, Maliyet/Fitness = 0.1777
# Parçacık 3: Pozisyon = -0.8397, Hız = 0.5500, Maliyet/Fitness = 0.7051
# Parçacık 4: Pozisyon = -0.2573, Hız = -0.7907, Maliyet/Fitness = 0.0662
# Parçacık 5: Pozisyon = -0.4120, Hız = -0.1332, Maliyet/Fitness = 0.1697
# Parçacık 6: Pozisyon = 0.1021, Hız = -0.3775, Maliyet/Fitness = 0.0104
# Parçacık 7: Pozisyon = -0.4131, Hız = -1.0258, Maliyet/Fitness = 0.1706
# Parçacık 8: Pozisyon = 1.7209, Hız = -0.5400, Maliyet/Fitness = 2.9613
# Parçacık 9: Pozisyon = 0.0054, Hız = -0.1608, Maliyet/Fitness = 0.0000
# Parçacık 10: Pozisyon = -0.4755, Hız = -0.4409, Maliyet/Fitness = 0.2261
# pbest: [0.0004, 0.0338, 0.0936, 0.0662, 0.0618, 0.0104, 0.0804, 0.0915, 0.0, 0.0012]
# gbest: 0.0000
#
# --- Iterasyon 8 ---
# Parçacık 1: Pozisyon = -0.0323, Hız = 0.1282, Maliyet/Fitness = 0.0010
# Parçacık 2: Pozisyon = 0.3231, Hız = -0.0985, Maliyet/Fitness = 0.1044
# Parçacık 3: Pozisyon = 0.7370, Hız = 1.5767, Maliyet/Fitness = 0.5432
# Parçacık 4: Pozisyon = -0.3693, Hız = -0.1120, Maliyet/Fitness = 0.1364
# Parçacık 5: Pozisyon = -0.1095, Hız = 0.3025, Maliyet/Fitness = 0.0120
# Parçacık 6: Pozisyon = -0.1127, Hız = -0.2148, Maliyet/Fitness = 0.0127
# Parçacık 7: Pozisyon = -0.4222, Hız = -0.0092, Maliyet/Fitness = 0.1783
# Parçacık 8: Pozisyon = -0.1940, Hız = -1.9148, Maliyet/Fitness = 0.0376
# Parçacık 9: Pozisyon = -0.0750, Hız = -0.0804, Maliyet/Fitness = 0.0056
# Parçacık 10: Pozisyon = -0.1157, Hız = 0.3598, Maliyet/Fitness = 0.0134
# pbest: [0.0004, 0.0338, 0.0936, 0.0662, 0.012, 0.0104, 0.0804, 0.0376, 0.0, 0.0012]
# gbest: 0.0000
#
# --- Iterasyon 9 ---
# Parçacık 1: Pozisyon = -0.0263, Hız = 0.0060, Maliyet/Fitness = 0.0007
# Parçacık 2: Pozisyon = 0.1007, Hız = -0.2224, Maliyet/Fitness = 0.0101
# Parçacık 3: Pozisyon = 0.3552, Hız = -0.3819, Maliyet/Fitness = 0.1261
# Parçacık 4: Pozisyon = -0.3200, Hız = 0.0493, Maliyet/Fitness = 0.1024
# Parçacık 5: Pozisyon = 0.0869, Hız = 0.1964, Maliyet/Fitness = 0.0076
# Parçacık 6: Pozisyon = -0.1649, Hız = -0.0523, Maliyet/Fitness = 0.0272
# Parçacık 7: Pozisyon = 0.1551, Hız = 0.5773, Maliyet/Fitness = 0.0240
# Parçacık 8: Pozisyon = -1.0160, Hız = -0.8220, Maliyet/Fitness = 1.0323
# Parçacık 9: Pozisyon = -0.0483, Hız = 0.0267, Maliyet/Fitness = 0.0023
# Parçacık 10: Pozisyon = 0.1296, Hız = 0.2453, Maliyet/Fitness = 0.0168
# pbest: [0.0004, 0.0101, 0.0936, 0.0662, 0.0076, 0.0104, 0.024, 0.0376, 0.0, 0.0012]
# gbest: 0.0000
#
# --- Iterasyon 10 ---
# Parçacık 1: Pozisyon = -0.0303, Hız = -0.0041, Maliyet/Fitness = 0.0009
# Parçacık 2: Pozisyon = -0.1947, Hız = -0.2954, Maliyet/Fitness = 0.0379
# Parçacık 3: Pozisyon = -0.8024, Hız = -1.1576, Maliyet/Fitness = 0.6439
# Parçacık 4: Pozisyon = 0.0241, Hız = 0.3441, Maliyet/Fitness = 0.0006
# Parçacık 5: Pozisyon = 0.1512, Hız = 0.0642, Maliyet/Fitness = 0.0229
# Parçacık 6: Pozisyon = 0.2133, Hız = 0.3783, Maliyet/Fitness = 0.0455
# Parçacık 7: Pozisyon = 0.2276, Hız = 0.0726, Maliyet/Fitness = 0.0518
# Parçacık 8: Pozisyon = 0.5927, Hız = 1.6087, Maliyet/Fitness = 0.3513
# Parçacık 9: Pozisyon = -0.0033, Hız = 0.0449, Maliyet/Fitness = 0.0000
# Parçacık 10: Pozisyon = 0.0666, Hız = -0.0629, Maliyet/Fitness = 0.0044
# pbest: [0.0004, 0.0101, 0.0936, 0.0006, 0.0076, 0.0104, 0.024, 0.0376, 0.0, 0.0012]
# gbest: 0.0000
#
# Global Best Pozisyon: [-0.00333904]
# Global Best : [1.11491765e-05]
