# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtalas/SezgiselOtimizasyonDersNotlari/blob/main/PSOx2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# Optimize etmek istediğimiz fonksiyon: f(x) = x^2
def cost_function(x):
    return x ** 2

# PSO parametreleri
w = 0.5  # Eylemsizlik katsayısı
c1 = 1.2  # Bireysel öğrenme katsayısı (cognitive component)
c2 = 1.5  # Sosyal öğrenme katsayısı (social component)
n_particles = 10  # Parçacık sayısı
n_iterations = 10  # İterasyon sayısı
dimension = 1  # Tek boyutlu problem (x)

# Parçacıkların başlangıç pozisyonları ve hızları
particles_pos = np.random.uniform(-10, 10, (n_particles, dimension))  # [-10, 10] aralığında rastgele başlat
particles_vel = np.random.uniform(-1, 1, (n_particles, dimension))    # Başlangıç hızları [-1, 1] aralığında

# Her parçacık için en iyi pozisyon (pbest) ve en iyi değerler
pbest_pos = np.copy(particles_pos)
pbest_val = np.array([cost_function(p) for p in pbest_pos])

# Global en iyi pozisyon ve değeri (gbest)
gbest_pos = pbest_pos[np.argmin(pbest_val)]
gbest_val = np.min(pbest_val)

# PSO algoritması
for iteration in range(n_iterations):
    print(f"--- Iterasyon {iteration + 1} ---")

    # Her parçacık için hız ve pozisyon güncellemeleri
    for i in range(n_particles):
        r1, r2 = np.random.rand(2)  # Rastgele sayılar

        # Hız güncellemesi (velocity update)
        particles_vel[i] = (w * particles_vel[i] +
                            c1 * r1 * (pbest_pos[i] - particles_pos[i]) +
                            c2 * r2 * (gbest_pos - particles_pos[i]))

        # Pozisyon güncellemesi (position update)

        particles_pos[i] =  particles_pos[i] + particles_vel[i]

        # Bu pozisyondaki değeri hesapla
        fitness_value = cost_function(particles_pos[i])

        # pbest güncellemesi
        if fitness_value < pbest_val[i]:
            pbest_pos[i] = particles_pos[i]
            pbest_val[i] = fitness_value

        # gbest güncellemesi
        if fitness_value < gbest_val:
            gbest_pos = particles_pos[i]
            gbest_val = fitness_value

        # Parçacık bilgilerini yazdır
        print(f"Parçacık {i+1}: Pozisyon = {particles_pos[i][0]:.4f}, Hız = {particles_vel[i][0]:.4f}, Maliyet/Fitness = {fitness_value[0]:.4f}")

    # pbest ve gbest bilgilerini yazdır
    print(f"pbest: {[round(val[0], 4) for val in pbest_val]}")
    print(f"gbest: {gbest_val[0]:.4f}\n")

print(f"Global Best Pozisyon: {gbest_pos[0]}")
print(f"Global Best : {gbest_val[0]}")
# Out:
# --- Iterasyon 1 ---
# Parçacık 1: Pozisyon = -1.0788, Hız = -0.4944, Maliyet/Fitness = 1.1639
# Parçacık 2: Pozisyon = -0.1025, Hız = 4.3007, Maliyet/Fitness = 0.0105
# Parçacık 3: Pozisyon = -3.4481, Hız = -12.7733, Maliyet/Fitness = 11.8897
# Parçacık 4: Pozisyon = 5.5899, Hız = -1.5084, Maliyet/Fitness = 31.2474
# Parçacık 5: Pozisyon = 2.8742, Hız = 10.0433, Maliyet/Fitness = 8.2613
# Parçacık 6: Pozisyon = -0.4128, Hız = -1.9548, Maliyet/Fitness = 0.1704
# Parçacık 7: Pozisyon = 0.2907, Hız = -0.4968, Maliyet/Fitness = 0.0845
# Parçacık 8: Pozisyon = 0.7153, Hız = -0.9834, Maliyet/Fitness = 0.5117
# Parçacık 9: Pozisyon = -2.7423, Hız = -11.2198, Maliyet/Fitness = 7.5202
# Parçacık 10: Pozisyon = -3.4107, Hız = 5.0607, Maliyet/Fitness = 11.6327
# pbest: [0.3415, 0.0105, 11.8897, 31.2474, 8.2613, 0.1704, 0.0845, 0.5117, 7.5202, 11.6327]
# gbest: 0.0105
#
# --- Iterasyon 2 ---
# Parçacık 1: Pozisyon = -0.0766, Hız = 1.0022, Maliyet/Fitness = 0.0059
# Parçacık 2: Pozisyon = 2.0862, Hız = 2.1887, Maliyet/Fitness = 4.3521
# Parçacık 3: Pozisyon = -8.2552, Hız = -4.8071, Maliyet/Fitness = 68.1490
# Parçacık 4: Pozisyon = -1.5291, Hız = -7.1190, Maliyet/Fitness = 2.3381
# Parçacık 5: Pozisyon = 4.7997, Hız = 1.9255, Maliyet/Fitness = 23.0372
# Parçacık 6: Pozisyon = -1.2385, Hız = -0.8257, Maliyet/Fitness = 1.5338
# Parçacık 7: Pozisyon = -0.3046, Hız = -0.5952, Maliyet/Fitness = 0.0928
# Parçacık 8: Pozisyon = 0.0393, Hız = -0.6761, Maliyet/Fitness = 0.0015
# Parçacık 9: Pozisyon = -7.1447, Hız = -4.4024, Maliyet/Fitness = 51.0470
# Parçacık 10: Pozisyon = 3.6791, Hız = 7.0898, Maliyet/Fitness = 13.5358
# pbest: [0.0059, 0.0105, 11.8897, 2.3381, 8.2613, 0.1704, 0.0845, 0.0015, 7.5202, 11.6327]
# gbest: 0.0015
#
# --- Iterasyon 3 ---
# Parçacık 1: Pozisyon = 0.5275, Hız = 0.6041, Maliyet/Fitness = 0.2782
# Parçacık 2: Pozisyon = -0.5632, Hız = -2.6494, Maliyet/Fitness = 0.3172
# Parçacık 3: Pozisyon = -5.1334, Hız = 3.1218, Maliyet/Fitness = 26.3521
# Parçacık 4: Pozisyon = -4.7712, Hız = -3.2421, Maliyet/Fitness = 22.7646
# Parçacık 5: Pozisyon = -0.4792, Hız = -5.2789, Maliyet/Fitness = 0.2296
# Parçacık 6: Pozisyon = 0.2832, Hız = 1.5217, Maliyet/Fitness = 0.0802
# Parçacık 7: Pozisyon = -0.0450, Hız = 0.2596, Maliyet/Fitness = 0.0020
# Parçacık 8: Pozisyon = -0.2988, Hız = -0.3380, Maliyet/Fitness = 0.0893
# Parçacık 9: Pozisyon = -0.8844, Hız = 6.2604, Maliyet/Fitness = 0.7821
# Parçacık 10: Pozisyon = 0.6920, Hız = -2.9871, Maliyet/Fitness = 0.4788
# pbest: [0.0059, 0.0105, 11.8897, 2.3381, 0.2296, 0.0802, 0.002, 0.0015, 0.7821, 0.4788]
# gbest: 0.0015
#
# --- Iterasyon 4 ---
# Parçacık 1: Pozisyon = -0.2164, Hız = -0.7439, Maliyet/Fitness = 0.0468
# Parçacık 2: Pozisyon = -1.2072, Hız = -0.6440, Maliyet/Fitness = 1.4573
# Parçacık 3: Pozisyon = 5.0582, Hız = 10.1916, Maliyet/Fitness = 25.5852
# Parçacık 4: Pozisyon = -1.7761, Hız = 2.9951, Maliyet/Fitness = 3.1547
# Parçacık 5: Pozisyon = -3.0781, Hız = -2.5989, Maliyet/Fitness = 9.4748
# Parçacık 6: Pozisyon = 0.6327, Hız = 0.3495, Maliyet/Fitness = 0.4003
# Parçacık 7: Pozisyon = -0.0145, Hız = 0.0305, Maliyet/Fitness = 0.0002
# Parçacık 8: Pozisyon = 0.1370, Hız = 0.4357, Maliyet/Fitness = 0.0188
# Parçacık 9: Pozisyon = 3.0032, Hız = 3.8876, Maliyet/Fitness = 9.0195
# Parçacık 10: Pozisyon = -1.1406, Hız = -1.8326, Maliyet/Fitness = 1.3010
# pbest: [0.0059, 0.0105, 11.8897, 2.3381, 0.2296, 0.0802, 0.0002, 0.0015, 0.7821, 0.4788]
# gbest: 0.0002
#
# --- Iterasyon 5 ---
# Parçacık 1: Pozisyon = -0.3097, Hız = -0.0932, Maliyet/Fitness = 0.0959
# Parçacık 2: Pozisyon = 0.2855, Hız = 1.4927, Maliyet/Fitness = 0.0815
# Parçacık 3: Pozisyon = -3.5996, Hız = -8.6578, Maliyet/Fitness = 12.9572
# Parçacık 4: Pozisyon = 0.4463, Hız = 2.2225, Maliyet/Fitness = 0.1992
# Parçacık 5: Pozisyon = 2.6166, Hız = 5.6947, Maliyet/Fitness = 6.8465
# Parçacık 6: Pozisyon = -0.1019, Hız = -0.7346, Maliyet/Fitness = 0.0104
# Parçacık 7: Pozisyon = 0.0008, Hız = 0.0153, Maliyet/Fitness = 0.0000
# Parçacık 8: Pozisyon = 0.2130, Hız = 0.0760, Maliyet/Fitness = 0.0454
# Parçacık 9: Pozisyon = 0.4052, Hız = -2.5981, Maliyet/Fitness = 0.1642
# Parçacık 10: Pozisyon = 1.5226, Hız = 2.6632, Maliyet/Fitness = 2.3182
# pbest: [0.0059, 0.0105, 11.8897, 0.1992, 0.2296, 0.0104, 0.0, 0.0015, 0.1642, 0.4788]
# gbest: 0.0000
#
# --- Iterasyon 6 ---
# Parçacık 1: Pozisyon = -0.0523, Hız = 0.2574, Maliyet/Fitness = 0.0027
# Parçacık 2: Pozisyon = 0.1695, Hız = -0.1160, Maliyet/Fitness = 0.0287
# Parçacık 3: Pozisyon = -7.1184, Hız = -3.5188, Maliyet/Fitness = 50.6720
# Parçacık 4: Pozisyon = 1.1417, Hız = 0.6954, Maliyet/Fitness = 1.3035
# Parçacık 5: Pozisyon = 3.4757, Hız = 0.8591, Maliyet/Fitness = 12.0804
# Parçacık 6: Pozisyon = -0.3188, Hız = -0.2169, Maliyet/Fitness = 0.1016
# Parçacık 7: Pozisyon = 0.0084, Hız = 0.0076, Maliyet/Fitness = 0.0001
# Parçacık 8: Pozisyon = -0.1598, Hız = -0.3728, Maliyet/Fitness = 0.0255
# Parçacık 9: Pozisyon = -1.3965, Hız = -1.8016, Maliyet/Fitness = 1.9501
# Parçacık 10: Pozisyon = 1.1638, Hız = -0.3587, Maliyet/Fitness = 1.3545
# pbest: [0.0027, 0.0105, 11.8897, 0.1992, 0.2296, 0.0104, 0.0, 0.0015, 0.1642, 0.4788]
# gbest: 0.0000
#
# --- Iterasyon 7 ---
# Parçacık 1: Pozisyon = 0.0879, Hız = 0.1402, Maliyet/Fitness = 0.0077
# Parçacık 2: Pozisyon = 0.0207, Hız = -0.1488, Maliyet/Fitness = 0.0004
# Parçacık 3: Pozisyon = -0.6640, Hız = 6.4544, Maliyet/Fitness = 0.4409
# Parçacık 4: Pozisyon = 0.7051, Hız = -0.4366, Maliyet/Fitness = 0.4972
# Parçacık 5: Pozisyon = 0.7078, Hız = -2.7679, Maliyet/Fitness = 0.5009
# Parçacık 6: Pozisyon = -0.3098, Hız = 0.0090, Maliyet/Fitness = 0.0959
# Parçacık 7: Pozisyon = 0.0079, Hız = -0.0006, Maliyet/Fitness = 0.0001
# Parçacık 8: Pozisyon = -0.1159, Hız = 0.0439, Maliyet/Fitness = 0.0134
# Parçacık 9: Pozisyon = -0.4193, Hız = 0.9772, Maliyet/Fitness = 0.1758
# Parçacık 10: Pozisyon = 0.1859, Hız = -0.9779, Maliyet/Fitness = 0.0346
# pbest: [0.0027, 0.0004, 0.4409, 0.1992, 0.2296, 0.0104, 0.0, 0.0015, 0.1642, 0.0346]
# gbest: 0.0000
#
# --- Iterasyon 8 ---
# Parçacık 1: Pozisyon = -0.0035, Hız = -0.0914, Maliyet/Fitness = 0.0000
# Parçacık 2: Pozisyon = -0.0682, Hız = -0.0889, Maliyet/Fitness = 0.0047
# Parçacık 3: Pozisyon = 3.4978, Hız = 4.1618, Maliyet/Fitness = 12.2345
# Parçacık 4: Pozisyon = -0.1208, Hız = -0.8260, Maliyet/Fitness = 0.0146
# Parçacık 5: Pozisyon = -2.6104, Hız = -3.3181, Maliyet/Fitness = 6.8139
# Parçacık 6: Pozisyon = -0.0706, Hız = 0.2391, Maliyet/Fitness = 0.0050
# Parçacık 7: Pozisyon = 0.0043, Hız = -0.0036, Maliyet/Fitness = 0.0000
# Parçacık 8: Pozisyon = -0.0248, Hız = 0.0911, Maliyet/Fitness = 0.0006
# Parçacık 9: Pozisyon = 0.3799, Hız = 0.7991, Maliyet/Fitness = 0.1443
# Parçacık 10: Pozisyon = -0.5661, Hız = -0.7520, Maliyet/Fitness = 0.3204
# pbest: [0.0, 0.0004, 0.4409, 0.0146, 0.2296, 0.005, 0.0, 0.0006, 0.1443, 0.0346]
# gbest: 0.0000
#
# --- Iterasyon 9 ---
# Parçacık 1: Pozisyon = -0.0454, Hız = -0.0419, Maliyet/Fitness = 0.0021
# Parçacık 2: Pozisyon = 0.0034, Hız = 0.0716, Maliyet/Fitness = 0.0000
# Parçacık 3: Pozisyon = 0.8363, Hız = -2.6615, Maliyet/Fitness = 0.6993
# Parçacık 4: Pozisyon = -0.3878, Hız = -0.2670, Maliyet/Fitness = 0.1504
# Parçacık 5: Pozisyon = 0.4301, Hız = 3.0405, Maliyet/Fitness = 0.1850
# Parçacık 6: Pozisyon = 0.1039, Hız = 0.1745, Maliyet/Fitness = 0.0108
# Parçacık 7: Pozisyon = -0.0011, Hız = -0.0054, Maliyet/Fitness = 0.0000
# Parçacık 8: Pozisyon = 0.0458, Hız = 0.0705, Maliyet/Fitness = 0.0021
# Parçacık 9: Pozisyon = 0.7725, Hız = 0.3926, Maliyet/Fitness = 0.5967
# Parçacık 10: Pozisyon = -0.4001, Hız = 0.1659, Maliyet/Fitness = 0.1601
# pbest: [0.0, 0.0, 0.4409, 0.0146, 0.185, 0.005, 0.0, 0.0006, 0.1443, 0.0346]
# gbest: 0.0000
#
# --- Iterasyon 10 ---
# Parçacık 1: Pozisyon = 0.0175, Hız = 0.0629, Maliyet/Fitness = 0.0003
# Parçacık 2: Pozisyon = 0.0327, Hız = 0.0293, Maliyet/Fitness = 0.0011
# Parçacık 3: Pozisyon = -2.1986, Hız = -3.0348, Maliyet/Fitness = 4.8337
# Parçacık 4: Pozisyon = 0.1855, Hız = 0.5733, Maliyet/Fitness = 0.0344
# Parçacık 5: Pozisyon = 1.8658, Hız = 1.4357, Maliyet/Fitness = 3.4812
# Parçacık 6: Pozisyon = -0.1085, Hız = -0.2124, Maliyet/Fitness = 0.0118
# Parçacık 7: Pozisyon = -0.0035, Hız = -0.0024, Maliyet/Fitness = 0.0000
# Parçacık 8: Pozisyon = 0.0621, Hız = 0.0163, Maliyet/Fitness = 0.0039
# Parçacık 9: Pozisyon = 0.4880, Hız = -0.2845, Maliyet/Fitness = 0.2381
# Parçacık 10: Pozisyon = 0.8351, Hız = 1.2353, Maliyet/Fitness = 0.6975
# pbest: [0.0, 0.0, 0.4409, 0.0146, 0.185, 0.005, 0.0, 0.0006, 0.1443, 0.0346]
# gbest: 0.0000
#
# Global Best Pozisyon: -0.0035287643819668264
# Global Best : 6.52429662859185e-07
