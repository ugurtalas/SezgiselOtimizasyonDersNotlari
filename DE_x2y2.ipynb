# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtalas/SezgiselOtimizasyonDersNotlari/blob/main/DE_x2y2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Parametreler
pop_size = 5       # Popülasyon boyutu
dimensions = 2     # Boyut (2D olarak güncellendi)
mutation_factor = 0.8
crossover_rate = 0.7
iterations = 10    # İterasyon sayısı

# Hedef fonksiyon f(x, y) = x^2 + y^2
def objective_function(x):
    return x[0] ** 2 + x[1] ** 2

# Başlangıç popülasyonu oluştur (2D)
population = np.random.uniform(-5.12, 5.12, (pop_size, dimensions))

# Her iterasyonda işlemleri ekrana yazdır ve grafiği çizdir
for i in range(iterations):
    print(f"\nIteration {i + 1}")
    new_population = np.copy(population)
    print(f"Populasyon: {new_population}")
    print("\n")

    # Bireyleri işleyin
    for j in range(pop_size):
        # Üç rastgele farklı birey seç
        indices = np.random.choice(pop_size, 3, replace=False)
        while j in indices:
            indices = np.random.choice(pop_size, 3, replace=False)
        print("İşlem yapılan birey ", population[j])
        a, b, c = population[indices]
        mutant = a + mutation_factor * (b - c)
        print("Rastgele seçilen 3 birey : xr1", a, " xr2", b, "  xr3", c )
        # Mutasyon ve çaprazlama
        print("Fark Vektörü : ", mutant)

        trial = np.copy(population[j])



        for d in range(dimensions):
          rn = np.random.rand()
          print("Random Sayı : ", rn, "  CR : ", crossover_rate)
          if rn < crossover_rate:
            trial[d] = mutant[d]

        ui = trial
        print("ui : ", ui)

        # Değerlendirme
        if objective_function(trial) < objective_function(population[j]):
            new_population[j] = trial
            print("ui seçildi")
        else:
            print("Xi Devam")

        # Hesaplamaları yazdır
        print(f"Birey {j + 1}: Xi = {population[j]}, ui = {trial}, "
              f" xi Fitness= {objective_function(population[j]):.4f}, "
              f" ui Fitness = {objective_function(trial):.4f}")
        print("\n\n")

    # Popülasyonu güncelle
    population = new_population

    # Grafik çizimi için hazırlık
    x_values = np.linspace(-5.12, 5.12, 100)
    y_values = np.linspace(-5.12, 5.12, 100)
    X, Y = np.meshgrid(x_values, y_values)
    Z = X ** 2 + Y ** 2  # f(x, y) = x^2 + y^2

    # Grafik çizimi
    fig = plt.figure(figsize=(18, 6))

    # 3D Surface plot
    ax1 = fig.add_subplot(131, projection='3d')
    ax1.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.7)
    ax1.scatter(population[:, 0], population[:, 1], [objective_function(ind) for ind in population], color='red')
    ax1.set_title(f'3D Surface Plot (Iteration {i + 1})')
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y')
    ax1.set_zlabel('Fitness')

    # Contour plot
    ax2 = fig.add_subplot(132)
    contour = ax2.contourf(X, Y, Z, levels=50, cmap='viridis')
    fig.colorbar(contour, ax=ax2)
    ax2.scatter(population[:, 0], population[:, 1], color='red', label='Individuals')
    ax2.set_title(f'Contour Plot (Iteration {i + 1})')
    ax2.set_xlabel('X')
    ax2.set_ylabel('Y')
    ax2.legend()

    # 2D Scatter plot of population on the function f(x, y) = x^2 + y^2
    ax3 = fig.add_subplot(133)
    z_values = [objective_function([x, y]) for x, y in population]
    ax3.plot(x_values, [objective_function([x, 0]) for x in x_values], label='Objective Function (1D Slice)', color='orange')
    ax3.scatter(population[:, 0], z_values, color='blue', label='Individuals')
    ax3.set_title(f'Population on Objective Function (Iteration {i + 1})')
    ax3.set_xlabel('X')
    ax3.set_ylabel('Fitness')
    ax3.legend()
    ax3.grid(True)

    plt.show()

# Sonuç
best_individual = min(population, key=objective_function)
print("\nBest solution found:", best_individual)
print("Objective value:", objective_function(best_individual))
# Out:
# Iteration 1
# Populasyon: [[-2.49524545 -0.80438281]
#  [-4.93348818  0.71325557]
#  [-3.09296059  1.6477872 ]
#  [ 0.4939867  -2.9706423 ]
#  [ 3.1752      0.24648212]]
#
#
# İşlem yapılan birey  [-2.49524545 -0.80438281]
# Rastgele seçilen 3 birey : xr1 [ 0.4939867 -2.9706423]  xr2 [-3.09296059  1.6477872 ]   xr3 [-4.93348818  0.71325557]
# Fark Vektörü :  [ 1.96640877 -2.223017  ]
# Random Sayı :  0.17955132793634188   CR :  0.7
# Random Sayı :  0.47923333515388566   CR :  0.7
# ui :  [ 1.96640877 -2.223017  ]
# Xi Devam
# Birey 1: Xi = [-2.49524545 -0.80438281], ui = [ 1.96640877 -2.223017  ],  xi Fitness= 6.8733,  ui Fitness = 8.8086
#
#
#
# İşlem yapılan birey  [-4.93348818  0.71325557]
# Rastgele seçilen 3 birey : xr1 [-3.09296059  1.6477872 ]  xr2 [ 0.4939867 -2.9706423]   xr3 [3.1752     0.24648212]
# Fark Vektörü :  [-5.23793123 -0.92591234]
# Random Sayı :  0.23243914829030776   CR :  0.7
# Random Sayı :  0.7078994018518499   CR :  0.7
# ui :  [-5.23793123  0.71325557]
# Xi Devam
# Birey 2: Xi = [-4.93348818  0.71325557], ui = [-5.23793123  0.71325557],  xi Fitness= 24.8480,  ui Fitness = 27.9447
#
#
#
# İşlem yapılan birey  [-3.09296059  1.6477872 ]
# Rastgele seçilen 3 birey : xr1 [3.1752     0.24648212]  xr2 [-2.49524545 -0.80438281]   xr3 [-4.93348818  0.71325557]
# Fark Vektörü :  [ 5.12579418 -0.96762858]
# Random Sayı :  0.7881768019451305   CR :  0.7
# Random Sayı :  0.22620479374453262   CR :  0.7
# ui :  [-3.09296059 -0.96762858]
# ui seçildi
# Birey 3: Xi = [-3.09296059  1.6477872 ], ui = [-3.09296059 -0.96762858],  xi Fitness= 12.2816,  ui Fitness = 10.5027
#
#
#
# İşlem yapılan birey  [ 0.4939867 -2.9706423]
# Rastgele seçilen 3 birey : xr1 [-4.93348818  0.71325557]  xr2 [-2.49524545 -0.80438281]   xr3 [-3.09296059  1.6477872 ]
# Fark Vektörü :  [-4.45531607 -1.24848043]
# Random Sayı :  0.1980964286431901   CR :  0.7
# Random Sayı :  0.31977353751923476   CR :  0.7
# ui :  [-4.45531607 -1.24848043]
# Xi Devam
# Birey 4: Xi = [ 0.4939867 -2.9706423], ui = [-4.45531607 -1.24848043],  xi Fitness= 9.0687,  ui Fitness = 21.4085
#
#
#
# İşlem yapılan birey  [3.1752     0.24648212]
# Rastgele seçilen 3 birey : xr1 [-3.09296059  1.6477872 ]  xr2 [-2.49524545 -0.80438281]   xr3 [-4.93348818  0.71325557]
# Fark Vektörü :  [-1.1423664   0.43367649]
# Random Sayı :  0.6452088785843583   CR :  0.7
# Random Sayı :  0.9486381797574918   CR :  0.7
# ui :  [-1.1423664   0.24648212]
# ui seçildi
# Birey 5: Xi = [3.1752     0.24648212], ui = [-1.1423664   0.24648212],  xi Fitness= 10.1426,  ui Fitness = 1.3658
# Iteration 2
# Populasyon: [[-2.49524545 -0.80438281]
#  [-4.93348818  0.71325557]
#  [-3.09296059 -0.96762858]
#  [ 0.4939867  -2.9706423 ]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-2.49524545 -0.80438281]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [ 0.4939867 -2.9706423]   xr3 [-4.93348818  0.71325557]
# Fark Vektörü :  [ 3.1996135  -2.70063617]
# Random Sayı :  0.8762735983050292   CR :  0.7
# Random Sayı :  0.5643337637528706   CR :  0.7
# ui :  [-2.49524545 -2.70063617]
# Xi Devam
# Birey 1: Xi = [-2.49524545 -0.80438281], ui = [-2.49524545 -2.70063617],  xi Fitness= 6.8733,  ui Fitness = 13.5197
#
#
#
# İşlem yapılan birey  [-4.93348818  0.71325557]
# Rastgele seçilen 3 birey : xr1 [ 0.4939867 -2.9706423]  xr2 [-1.1423664   0.24648212]   xr3 [-3.09296059 -0.96762858]
# Fark Vektörü :  [ 2.05446205 -1.99935373]
# Random Sayı :  0.9351277356260596   CR :  0.7
# Random Sayı :  0.1666636519286817   CR :  0.7
# ui :  [-4.93348818 -1.99935373]
# Xi Devam
# Birey 2: Xi = [-4.93348818  0.71325557], ui = [-4.93348818 -1.99935373],  xi Fitness= 24.8480,  ui Fitness = 28.3367
#
#
#
# İşlem yapılan birey  [-3.09296059 -0.96762858]
# Rastgele seçilen 3 birey : xr1 [ 0.4939867 -2.9706423]  xr2 [-2.49524545 -0.80438281]   xr3 [-4.93348818  0.71325557]
# Fark Vektörü :  [ 2.44458088 -4.184753  ]
# Random Sayı :  0.8099166145466737   CR :  0.7
# Random Sayı :  0.8501280100538173   CR :  0.7
# ui :  [-3.09296059 -0.96762858]
# Xi Devam
# Birey 3: Xi = [-3.09296059 -0.96762858], ui = [-3.09296059 -0.96762858],  xi Fitness= 10.5027,  ui Fitness = 10.5027
#
#
#
# İşlem yapılan birey  [ 0.4939867 -2.9706423]
# Rastgele seçilen 3 birey : xr1 [-4.93348818  0.71325557]  xr2 [-3.09296059 -0.96762858]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [-6.49396353 -0.25803299]
# Random Sayı :  0.24348946438507013   CR :  0.7
# Random Sayı :  0.7186952531885019   CR :  0.7
# ui :  [-6.49396353 -2.9706423 ]
# Xi Devam
# Birey 4: Xi = [ 0.4939867 -2.9706423], ui = [-6.49396353 -2.9706423 ],  xi Fitness= 9.0687,  ui Fitness = 50.9963
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [-2.49524545 -0.80438281]  xr2 [-4.93348818  0.71325557]   xr3 [-3.09296059 -0.96762858]
# Fark Vektörü :  [-3.96766752  0.54032451]
# Random Sayı :  0.9019014216545644   CR :  0.7
# Random Sayı :  0.36440896045060756   CR :  0.7
# ui :  [-1.1423664   0.54032451]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [-1.1423664   0.54032451],  xi Fitness= 1.3658,  ui Fitness = 1.5970
# Iteration 3
# Populasyon: [[-2.49524545 -0.80438281]
#  [-4.93348818  0.71325557]
#  [-3.09296059 -0.96762858]
#  [ 0.4939867  -2.9706423 ]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-2.49524545 -0.80438281]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [ 0.4939867 -2.9706423]   xr3 [-4.93348818  0.71325557]
# Fark Vektörü :  [ 3.1996135  -2.70063617]
# Random Sayı :  0.9133573459201807   CR :  0.7
# Random Sayı :  0.7424671490173955   CR :  0.7
# ui :  [-2.49524545 -0.80438281]
# Xi Devam
# Birey 1: Xi = [-2.49524545 -0.80438281], ui = [-2.49524545 -0.80438281],  xi Fitness= 6.8733,  ui Fitness = 6.8733
#
#
#
# İşlem yapılan birey  [-4.93348818  0.71325557]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [-3.09296059 -0.96762858]   xr3 [ 0.4939867 -2.9706423]
# Fark Vektörü :  [-4.01192423  1.8488931 ]
# Random Sayı :  0.4622548453582881   CR :  0.7
# Random Sayı :  0.4849876372615074   CR :  0.7
# ui :  [-4.01192423  1.8488931 ]
# ui seçildi
# Birey 2: Xi = [-4.93348818  0.71325557], ui = [-4.01192423  1.8488931 ],  xi Fitness= 24.8480,  ui Fitness = 19.5139
#
#
#
# İşlem yapılan birey  [-3.09296059 -0.96762858]
# Rastgele seçilen 3 birey : xr1 [-4.93348818  0.71325557]  xr2 [-2.49524545 -0.80438281]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [-6.01579141 -0.12743638]
# Random Sayı :  0.2541722728772484   CR :  0.7
# Random Sayı :  0.5703415774236397   CR :  0.7
# ui :  [-6.01579141 -0.12743638]
# Xi Devam
# Birey 3: Xi = [-3.09296059 -0.96762858], ui = [-6.01579141 -0.12743638],  xi Fitness= 10.5027,  ui Fitness = 36.2060
#
#
#
# İşlem yapılan birey  [ 0.4939867 -2.9706423]
# Rastgele seçilen 3 birey : xr1 [-4.93348818  0.71325557]  xr2 [-3.09296059 -0.96762858]   xr3 [-2.49524545 -0.80438281]
# Fark Vektörü :  [-5.41166029  0.58265895]
# Random Sayı :  0.9459143943532826   CR :  0.7
# Random Sayı :  0.07091942369820736   CR :  0.7
# ui :  [0.4939867  0.58265895]
# ui seçildi
# Birey 4: Xi = [ 0.4939867 -2.9706423], ui = [0.4939867  0.58265895],  xi Fitness= 9.0687,  ui Fitness = 0.5835
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [-4.93348818  0.71325557]  xr2 [ 0.4939867 -2.9706423]   xr3 [-2.49524545 -0.80438281]
# Fark Vektörü :  [-2.54210246 -1.01975202]
# Random Sayı :  0.7151990981797738   CR :  0.7
# Random Sayı :  0.7613673081303131   CR :  0.7
# ui :  [-1.1423664   0.24648212]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [-1.1423664   0.24648212],  xi Fitness= 1.3658,  ui Fitness = 1.3658
# Iteration 4
# Populasyon: [[-2.49524545 -0.80438281]
#  [-4.01192423  1.8488931 ]
#  [-3.09296059 -0.96762858]
#  [ 0.4939867   0.58265895]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-2.49524545 -0.80438281]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-4.01192423  1.8488931 ]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [-1.80165956  1.86458773]
# Random Sayı :  0.4900188079948472   CR :  0.7
# Random Sayı :  0.43859017054407456   CR :  0.7
# ui :  [-1.80165956  1.86458773]
# ui seçildi
# Birey 1: Xi = [-2.49524545 -0.80438281], ui = [-1.80165956  1.86458773],  xi Fitness= 6.8733,  ui Fitness = 6.7227
#
#
#
# İşlem yapılan birey  [-4.01192423  1.8488931 ]
# Rastgele seçilen 3 birey : xr1 [-2.49524545 -0.80438281]  xr2 [-1.1423664   0.24648212]   xr3 [0.4939867  0.58265895]
# Fark Vektörü :  [-3.80432793 -1.07332427]
# Random Sayı :  0.6004950572183906   CR :  0.7
# Random Sayı :  0.027798757102609928   CR :  0.7
# ui :  [-3.80432793 -1.07332427]
# ui seçildi
# Birey 2: Xi = [-4.01192423  1.8488931 ], ui = [-3.80432793 -1.07332427],  xi Fitness= 19.5139,  ui Fitness = 15.6249
#
#
#
# İşlem yapılan birey  [-3.09296059 -0.96762858]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [-2.49524545 -0.80438281]   xr3 [-4.01192423  1.8488931 ]
# Fark Vektörü :  [ 0.07097662 -1.8761386 ]
# Random Sayı :  0.8903419945417275   CR :  0.7
# Random Sayı :  0.9133238739631293   CR :  0.7
# ui :  [-3.09296059 -0.96762858]
# Xi Devam
# Birey 3: Xi = [-3.09296059 -0.96762858], ui = [-3.09296059 -0.96762858],  xi Fitness= 10.5027,  ui Fitness = 10.5027
#
#
#
# İşlem yapılan birey  [0.4939867  0.58265895]
# Rastgele seçilen 3 birey : xr1 [-4.01192423  1.8488931 ]  xr2 [-2.49524545 -0.80438281]   xr3 [-3.09296059 -0.96762858]
# Fark Vektörü :  [-3.53375212  1.97948971]
# Random Sayı :  0.27756214499247356   CR :  0.7
# Random Sayı :  0.9229591430959447   CR :  0.7
# ui :  [-3.53375212  0.58265895]
# Xi Devam
# Birey 4: Xi = [0.4939867  0.58265895], ui = [-3.53375212  0.58265895],  xi Fitness= 0.5835,  ui Fitness = 12.8269
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [-3.09296059 -0.96762858]  xr2 [0.4939867  0.58265895]   xr3 [-4.01192423  1.8488931 ]
# Fark Vektörü :  [ 0.51176816 -1.98061589]
# Random Sayı :  0.8528683677702045   CR :  0.7
# Random Sayı :  0.4400375068817157   CR :  0.7
# ui :  [-1.1423664  -1.98061589]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [-1.1423664  -1.98061589],  xi Fitness= 1.3658,  ui Fitness = 5.2278
# Iteration 5
# Populasyon: [[-1.80165956  1.86458773]
#  [-3.80432793 -1.07332427]
#  [-3.09296059 -0.96762858]
#  [ 0.4939867   0.58265895]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-1.80165956  1.86458773]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-1.1423664   0.24648212]   xr3 [-3.09296059 -0.96762858]
# Fark Vektörü :  [2.05446205 1.55394752]
# Random Sayı :  0.695780699971257   CR :  0.7
# Random Sayı :  0.43330709556792013   CR :  0.7
# ui :  [2.05446205 1.55394752]
# ui seçildi
# Birey 1: Xi = [-1.80165956  1.86458773], ui = [2.05446205 1.55394752],  xi Fitness= 6.7227,  ui Fitness = 6.6356
#
#
#
# İşlem yapılan birey  [-3.80432793 -1.07332427]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [-1.80165956  1.86458773]   xr3 [-3.09296059 -0.96762858]
# Fark Vektörü :  [-0.10932558  2.51225517]
# Random Sayı :  0.4716443628292485   CR :  0.7
# Random Sayı :  0.10768784663156572   CR :  0.7
# ui :  [-0.10932558  2.51225517]
# ui seçildi
# Birey 2: Xi = [-3.80432793 -1.07332427], ui = [-0.10932558  2.51225517],  xi Fitness= 15.6249,  ui Fitness = 6.3234
#
#
#
# İşlem yapılan birey  [-3.09296059 -0.96762858]
# Rastgele seçilen 3 birey : xr1 [-1.80165956  1.86458773]  xr2 [-1.1423664   0.24648212]   xr3 [0.4939867  0.58265895]
# Fark Vektörü :  [-3.11074204  1.59564627]
# Random Sayı :  0.11347972119970251   CR :  0.7
# Random Sayı :  0.3634157922523341   CR :  0.7
# ui :  [-3.11074204  1.59564627]
# Xi Devam
# Birey 3: Xi = [-3.09296059 -0.96762858], ui = [-3.11074204  1.59564627],  xi Fitness= 10.5027,  ui Fitness = 12.2228
#
#
#
# İşlem yapılan birey  [0.4939867  0.58265895]
# Rastgele seçilen 3 birey : xr1 [-3.09296059 -0.96762858]  xr2 [-3.80432793 -1.07332427]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [-5.22252981 -2.0234737 ]
# Random Sayı :  0.34599434192727774   CR :  0.7
# Random Sayı :  0.6188861684308193   CR :  0.7
# ui :  [-5.22252981 -2.0234737 ]
# Xi Devam
# Birey 4: Xi = [0.4939867  0.58265895], ui = [-5.22252981 -2.0234737 ],  xi Fitness= 0.5835,  ui Fitness = 31.3693
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-3.09296059 -0.96762858]   xr3 [-1.80165956  1.86458773]
# Fark Vektörü :  [-0.53905412 -1.6831141 ]
# Random Sayı :  0.07748790003626427   CR :  0.7
# Random Sayı :  0.65556167519273   CR :  0.7
# ui :  [-0.53905412 -1.6831141 ]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [-0.53905412 -1.6831141 ],  xi Fitness= 1.3658,  ui Fitness = 3.1235
# Iteration 6
# Populasyon: [[ 2.05446205  1.55394752]
#  [-0.10932558  2.51225517]
#  [-3.09296059 -0.96762858]
#  [ 0.4939867   0.58265895]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [2.05446205 1.55394752]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-1.1423664   0.24648212]   xr3 [-0.10932558  2.51225517]
# Fark Vektörü :  [-0.33244596 -1.22995949]
# Random Sayı :  0.1738719485653225   CR :  0.7
# Random Sayı :  0.40098089553119587   CR :  0.7
# ui :  [-0.33244596 -1.22995949]
# ui seçildi
# Birey 1: Xi = [2.05446205 1.55394752], ui = [-0.33244596 -1.22995949],  xi Fitness= 6.6356,  ui Fitness = 1.6233
#
#
#
# İşlem yapılan birey  [-0.10932558  2.51225517]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-3.09296059 -0.96762858]   xr3 [2.05446205 1.55394752]
# Fark Vektörü :  [-3.62395141 -1.43460193]
# Random Sayı :  0.2043751421020129   CR :  0.7
# Random Sayı :  0.323152510284184   CR :  0.7
# ui :  [-3.62395141 -1.43460193]
# Xi Devam
# Birey 2: Xi = [-0.10932558  2.51225517], ui = [-3.62395141 -1.43460193],  xi Fitness= 6.3234,  ui Fitness = 15.1911
#
#
#
# İşlem yapılan birey  [-3.09296059 -0.96762858]
# Rastgele seçilen 3 birey : xr1 [2.05446205 1.55394752]  xr2 [0.4939867  0.58265895]   xr3 [-0.10932558  2.51225517]
# Fark Vektörü :  [2.53711187 0.01027054]
# Random Sayı :  0.9520150817923805   CR :  0.7
# Random Sayı :  0.6314224711778456   CR :  0.7
# ui :  [-3.09296059  0.01027054]
# ui seçildi
# Birey 3: Xi = [-3.09296059 -0.96762858], ui = [-3.09296059  0.01027054],  xi Fitness= 10.5027,  ui Fitness = 9.5665
#
#
#
# İşlem yapılan birey  [0.4939867  0.58265895]
# Rastgele seçilen 3 birey : xr1 [-3.09296059 -0.96762858]  xr2 [2.05446205 1.55394752]   xr3 [-0.10932558  2.51225517]
# Fark Vektörü :  [-1.36193048 -1.73427471]
# Random Sayı :  0.9470137794870527   CR :  0.7
# Random Sayı :  0.49417461569617127   CR :  0.7
# ui :  [ 0.4939867  -1.73427471]
# Xi Devam
# Birey 4: Xi = [0.4939867  0.58265895], ui = [ 0.4939867  -1.73427471],  xi Fitness= 0.5835,  ui Fitness = 3.2517
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [-0.10932558  2.51225517]  xr2 [-3.09296059 -0.96762858]   xr3 [0.4939867  0.58265895]
# Fark Vektörü :  [-2.97888341  1.27202515]
# Random Sayı :  0.761427063727636   CR :  0.7
# Random Sayı :  0.12072605190970209   CR :  0.7
# ui :  [-1.1423664   1.27202515]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [-1.1423664   1.27202515],  xi Fitness= 1.3658,  ui Fitness = 2.9230
# Iteration 7
# Populasyon: [[-0.33244596 -1.22995949]
#  [-0.10932558  2.51225517]
#  [-3.09296059  0.01027054]
#  [ 0.4939867   0.58265895]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-0.33244596 -1.22995949]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [-3.09296059  0.01027054]   xr3 [0.4939867  0.58265895]
# Fark Vektörü :  [-4.01192423 -0.21142861]
# Random Sayı :  0.11367642224322327   CR :  0.7
# Random Sayı :  0.9200699969634711   CR :  0.7
# ui :  [-4.01192423 -1.22995949]
# Xi Devam
# Birey 1: Xi = [-0.33244596 -1.22995949], ui = [-4.01192423 -1.22995949],  xi Fitness= 1.6233,  ui Fitness = 17.6083
#
#
#
# İşlem yapılan birey  [-0.10932558  2.51225517]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [0.4939867  0.58265895]   xr3 [-0.33244596 -1.22995949]
# Fark Vektörü :  [-0.48122028  1.69657688]
# Random Sayı :  0.027316847409801448   CR :  0.7
# Random Sayı :  0.16550218603729072   CR :  0.7
# ui :  [-0.48122028  1.69657688]
# ui seçildi
# Birey 2: Xi = [-0.10932558  2.51225517], ui = [-0.48122028  1.69657688],  xi Fitness= 6.3234,  ui Fitness = 3.1099
#
#
#
# İşlem yapılan birey  [-3.09296059  0.01027054]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-0.33244596 -1.22995949]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [ 1.14192305 -0.59849433]
# Random Sayı :  0.9795305831709281   CR :  0.7
# Random Sayı :  0.9951811416822767   CR :  0.7
# ui :  [-3.09296059  0.01027054]
# Xi Devam
# Birey 3: Xi = [-3.09296059  0.01027054], ui = [-3.09296059  0.01027054],  xi Fitness= 9.5665,  ui Fitness = 9.5665
#
#
#
# İşlem yapılan birey  [0.4939867  0.58265895]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [-3.09296059  0.01027054]   xr3 [-0.33244596 -1.22995949]
# Fark Vektörü :  [-3.35077811  1.23866615]
# Random Sayı :  0.006882347163038927   CR :  0.7
# Random Sayı :  0.7328056316540689   CR :  0.7
# ui :  [-3.35077811  0.58265895]
# Xi Devam
# Birey 4: Xi = [0.4939867  0.58265895], ui = [-3.35077811  0.58265895],  xi Fitness= 0.5835,  ui Fitness = 11.5672
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [-0.33244596 -1.22995949]  xr2 [0.4939867  0.58265895]   xr3 [-0.10932558  2.51225517]
# Fark Vektörü :  [ 0.15020387 -2.77363646]
# Random Sayı :  0.15332890636989516   CR :  0.7
# Random Sayı :  0.5729558655968329   CR :  0.7
# ui :  [ 0.15020387 -2.77363646]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [ 0.15020387 -2.77363646],  xi Fitness= 1.3658,  ui Fitness = 7.7156
# Iteration 8
# Populasyon: [[-0.33244596 -1.22995949]
#  [-0.48122028  1.69657688]
#  [-3.09296059  0.01027054]
#  [ 0.4939867   0.58265895]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-0.33244596 -1.22995949]
# Rastgele seçilen 3 birey : xr1 [-0.48122028  1.69657688]  xr2 [-3.09296059  0.01027054]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [-2.04169563  1.50760761]
# Random Sayı :  0.4817397897865324   CR :  0.7
# Random Sayı :  0.45313660009675794   CR :  0.7
# ui :  [-2.04169563  1.50760761]
# Xi Devam
# Birey 1: Xi = [-0.33244596 -1.22995949], ui = [-2.04169563  1.50760761],  xi Fitness= 1.6233,  ui Fitness = 6.4414
#
#
#
# İşlem yapılan birey  [-0.48122028  1.69657688]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [-0.33244596 -1.22995949]   xr3 [0.4939867  0.58265895]
# Fark Vektörü :  [-1.80351253 -1.20361263]
# Random Sayı :  0.49540557675991614   CR :  0.7
# Random Sayı :  0.9814163646072217   CR :  0.7
# ui :  [-1.80351253  1.69657688]
# Xi Devam
# Birey 2: Xi = [-0.48122028  1.69657688], ui = [-1.80351253  1.69657688],  xi Fitness= 3.1099,  ui Fitness = 6.1310
#
#
#
# İşlem yapılan birey  [-3.09296059  0.01027054]
# Rastgele seçilen 3 birey : xr1 [-1.1423664   0.24648212]  xr2 [-0.48122028  1.69657688]   xr3 [0.4939867  0.58265895]
# Fark Vektörü :  [-1.92253198  1.13761646]
# Random Sayı :  0.8768941890849514   CR :  0.7
# Random Sayı :  0.007719839081403501   CR :  0.7
# ui :  [-3.09296059  1.13761646]
# Xi Devam
# Birey 3: Xi = [-3.09296059  0.01027054], ui = [-3.09296059  1.13761646],  xi Fitness= 9.5665,  ui Fitness = 10.8606
#
#
#
# İşlem yapılan birey  [0.4939867  0.58265895]
# Rastgele seçilen 3 birey : xr1 [-0.33244596 -1.22995949]  xr2 [-1.1423664   0.24648212]   xr3 [-0.48122028  1.69657688]
# Fark Vektörü :  [-0.86136286 -2.39003529]
# Random Sayı :  0.9649064407877824   CR :  0.7
# Random Sayı :  0.095678384449422   CR :  0.7
# ui :  [ 0.4939867  -2.39003529]
# Xi Devam
# Birey 4: Xi = [0.4939867  0.58265895], ui = [ 0.4939867  -2.39003529],  xi Fitness= 0.5835,  ui Fitness = 5.9563
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-0.48122028  1.69657688]   xr3 [-0.33244596 -1.22995949]
# Fark Vektörü :  [0.37496724 2.92388804]
# Random Sayı :  0.004889845032162277   CR :  0.7
# Random Sayı :  0.49571756764728403   CR :  0.7
# ui :  [0.37496724 2.92388804]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [0.37496724 2.92388804],  xi Fitness= 1.3658,  ui Fitness = 8.6897
# Iteration 9
# Populasyon: [[-0.33244596 -1.22995949]
#  [-0.48122028  1.69657688]
#  [-3.09296059  0.01027054]
#  [ 0.4939867   0.58265895]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-0.33244596 -1.22995949]
# Rastgele seçilen 3 birey : xr1 [-0.48122028  1.69657688]  xr2 [0.4939867  0.58265895]   xr3 [-3.09296059  0.01027054]
# Fark Vektörü :  [2.38833755 2.15448761]
# Random Sayı :  0.5487777050086848   CR :  0.7
# Random Sayı :  0.9790816545675232   CR :  0.7
# ui :  [ 2.38833755 -1.22995949]
# Xi Devam
# Birey 1: Xi = [-0.33244596 -1.22995949], ui = [ 2.38833755 -1.22995949],  xi Fitness= 1.6233,  ui Fitness = 7.2170
#
#
#
# İşlem yapılan birey  [-0.48122028  1.69657688]
# Rastgele seçilen 3 birey : xr1 [-3.09296059  0.01027054]  xr2 [-1.1423664   0.24648212]   xr3 [0.4939867  0.58265895]
# Fark Vektörü :  [-4.40204307 -0.25867092]
# Random Sayı :  0.7361141920426308   CR :  0.7
# Random Sayı :  0.19946292694550394   CR :  0.7
# ui :  [-0.48122028 -0.25867092]
# ui seçildi
# Birey 2: Xi = [-0.48122028  1.69657688], ui = [-0.48122028 -0.25867092],  xi Fitness= 3.1099,  ui Fitness = 0.2985
#
#
#
# İşlem yapılan birey  [-3.09296059  0.01027054]
# Rastgele seçilen 3 birey : xr1 [-0.48122028  1.69657688]  xr2 [-1.1423664   0.24648212]   xr3 [-0.33244596 -1.22995949]
# Fark Vektörü :  [-1.12915664  2.87773016]
# Random Sayı :  0.5720467088379986   CR :  0.7
# Random Sayı :  0.04348390852710926   CR :  0.7
# ui :  [-1.12915664  2.87773016]
# ui seçildi
# Birey 3: Xi = [-3.09296059  0.01027054], ui = [-1.12915664  2.87773016],  xi Fitness= 9.5665,  ui Fitness = 9.5563
#
#
#
# İşlem yapılan birey  [0.4939867  0.58265895]
# Rastgele seçilen 3 birey : xr1 [-0.48122028  1.69657688]  xr2 [-0.33244596 -1.22995949]   xr3 [-3.09296059  0.01027054]
# Fark Vektörü :  [1.72719143 0.70439285]
# Random Sayı :  0.5137673749104527   CR :  0.7
# Random Sayı :  0.31564675748705073   CR :  0.7
# ui :  [1.72719143 0.70439285]
# Xi Devam
# Birey 4: Xi = [0.4939867  0.58265895], ui = [1.72719143 0.70439285],  xi Fitness= 0.5835,  ui Fitness = 3.4794
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [-0.33244596 -1.22995949]  xr2 [-3.09296059  0.01027054]   xr3 [-0.48122028  1.69657688]
# Fark Vektörü :  [-2.4218382  -2.57900455]
# Random Sayı :  0.6554347079145676   CR :  0.7
# Random Sayı :  0.1192200735860185   CR :  0.7
# ui :  [-2.4218382  -2.57900455]
# Xi Devam
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [-2.4218382  -2.57900455],  xi Fitness= 1.3658,  ui Fitness = 12.5166
# Iteration 10
# Populasyon: [[-0.33244596 -1.22995949]
#  [-0.48122028 -0.25867092]
#  [-1.12915664  2.87773016]
#  [ 0.4939867   0.58265895]
#  [-1.1423664   0.24648212]]
#
#
# İşlem yapılan birey  [-0.33244596 -1.22995949]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-0.48122028 -0.25867092]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [1.0229036  0.17853652]
# Random Sayı :  0.07527924422775822   CR :  0.7
# Random Sayı :  0.08183026787525671   CR :  0.7
# ui :  [1.0229036  0.17853652]
# ui seçildi
# Birey 1: Xi = [-0.33244596 -1.22995949], ui = [1.0229036  0.17853652],  xi Fitness= 1.6233,  ui Fitness = 1.0782
#
#
#
# İşlem yapılan birey  [-0.48122028 -0.25867092]
# Rastgele seçilen 3 birey : xr1 [-1.12915664  2.87773016]  xr2 [-1.1423664   0.24648212]   xr3 [-0.33244596 -1.22995949]
# Fark Vektörü :  [-1.77709299  4.05888345]
# Random Sayı :  0.9618949292406428   CR :  0.7
# Random Sayı :  0.39525263745128014   CR :  0.7
# ui :  [-0.48122028  4.05888345]
# Xi Devam
# Birey 2: Xi = [-0.48122028 -0.25867092], ui = [-0.48122028  4.05888345],  xi Fitness= 0.2985,  ui Fitness = 16.7061
#
#
#
# İşlem yapılan birey  [-1.12915664  2.87773016]
# Rastgele seçilen 3 birey : xr1 [0.4939867  0.58265895]  xr2 [-1.1423664   0.24648212]   xr3 [-0.48122028 -0.25867092]
# Fark Vektörü :  [-0.0349302   0.98678139]
# Random Sayı :  0.07262382462040018   CR :  0.7
# Random Sayı :  0.21227456580554638   CR :  0.7
# ui :  [-0.0349302   0.98678139]
# ui seçildi
# Birey 3: Xi = [-1.12915664  2.87773016], ui = [-0.0349302   0.98678139],  xi Fitness= 9.5563,  ui Fitness = 0.9750
#
#
#
# İşlem yapılan birey  [0.4939867  0.58265895]
# Rastgele seçilen 3 birey : xr1 [-0.48122028 -0.25867092]  xr2 [-0.33244596 -1.22995949]   xr3 [-1.1423664   0.24648212]
# Fark Vektörü :  [ 0.16671608 -1.43982421]
# Random Sayı :  0.40512410752697703   CR :  0.7
# Random Sayı :  0.7457781905808625   CR :  0.7
# ui :  [0.16671608 0.58265895]
# ui seçildi
# Birey 4: Xi = [0.4939867  0.58265895], ui = [0.16671608 0.58265895],  xi Fitness= 0.5835,  ui Fitness = 0.3673
#
#
#
# İşlem yapılan birey  [-1.1423664   0.24648212]
# Rastgele seçilen 3 birey : xr1 [-0.48122028 -0.25867092]  xr2 [0.4939867  0.58265895]   xr3 [-0.33244596 -1.22995949]
# Fark Vektörü :  [0.17992584 1.19142383]
# Random Sayı :  0.5830572993688217   CR :  0.7
# Random Sayı :  0.965874556165523   CR :  0.7
# ui :  [0.17992584 0.24648212]
# ui seçildi
# Birey 5: Xi = [-1.1423664   0.24648212], ui = [0.17992584 0.24648212],  xi Fitness= 1.3658,  ui Fitness = 0.0931
# Best solution found: [0.17992584 0.24648212]
# Objective value: 0.09312674668295508
