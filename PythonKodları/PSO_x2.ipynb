# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtalas/SezgiselOtimizasyonDersNotlari/blob/main/PSOx2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PSO x^2 Örneği
#
#
# Parçacık Sürü Optimizasyon algortimasının x^2 maliyet  fonksiyonu ile çalışma örneği yapılmıştır.
#
# Örnek üzerinde parametreler değiştirilerek sonuçlar gözlemlenebilir.

# %%
import numpy as np

# Optimize etmek istediğimiz fonksiyon: f(x) = x^2
def cost_function(x):
    return x ** 2

# PSO parametreleri
w = 0.5  # Eylemsizlik katsayısı
c1 = 1.2  # Bireysel öğrenme katsayısı (cognitive component)
c2 = 1.5  # Sosyal öğrenme katsayısı (social component)
n_particles = 10  # Parçacık sayısı
n_iterations = 10  # İterasyon sayısı
dimension = 1  # Tek boyutlu problem (x)

# Parçacıkların başlangıç pozisyonları ve hızları
particles_pos = np.random.uniform(-10, 10, (n_particles, dimension))  # [-10, 10] aralığında rastgele başlat
particles_vel = np.random.uniform(-1, 1, (n_particles, dimension))    # Başlangıç hızları [-1, 1] aralığında

# Her parçacık için en iyi pozisyon (pbest) ve en iyi değerler
pbest_pos = np.copy(particles_pos)
pbest_val = np.array([cost_function(p) for p in pbest_pos])

# Global en iyi pozisyon ve değeri (gbest)
gbest_pos = pbest_pos[np.argmin(pbest_val)]
gbest_val = np.min(pbest_val)

# PSO algoritması
for iteration in range(n_iterations):
    print(f"--- Iterasyon {iteration + 1} ---")

    # Her parçacık için hız ve pozisyon güncellemeleri
    for i in range(n_particles):
        r1, r2 = np.random.rand(2)  # Rastgele sayılar

        # Hız güncellemesi (velocity update)
        particles_vel[i] = (w * particles_vel[i] +
                            c1 * r1 * (pbest_pos[i] - particles_pos[i]) +
                            c2 * r2 * (gbest_pos - particles_pos[i]))

        # Pozisyon güncellemesi (position update)

        particles_pos[i] =  particles_pos[i] + particles_vel[i]

        # Bu pozisyondaki değeri hesapla
        fitness_value = cost_function(particles_pos[i])

        # pbest güncellemesi
        if fitness_value < pbest_val[i]:
            pbest_pos[i] = particles_pos[i]
            pbest_val[i] = fitness_value

        # gbest güncellemesi
        if fitness_value < gbest_val:
            gbest_pos = particles_pos[i]
            gbest_val = fitness_value

        # Parçacık bilgilerini yazdır
        print(f"Parçacık {i+1}: Pozisyon = {particles_pos[i][0]:.4f}, Hız = {particles_vel[i][0]:.4f}, Maliyet/Fitness = {fitness_value[0]:.4f}")

    # pbest ve gbest bilgilerini yazdır
    print(f"pbest: {[round(val[0], 4) for val in pbest_val]}")
    print(f"gbest: {gbest_val}\n")

print(f"Global Best Pozisyon: {gbest_pos}")
print(f"Global Best : {gbest_val}")
# Out:
# --- Iterasyon 1 ---
# Parçacık 1: Pozisyon = 2.6472, Hız = -6.6003, Maliyet/Fitness = 7.0074
# Parçacık 2: Pozisyon = 1.8792, Hız = 4.7475, Maliyet/Fitness = 3.5314
# Parçacık 3: Pozisyon = 0.5578, Hız = 7.5008, Maliyet/Fitness = 0.3112
# Parçacık 4: Pozisyon = -6.5411, Hız = 0.3676, Maliyet/Fitness = 42.7859
# Parçacık 5: Pozisyon = 0.2220, Hız = -4.6094, Maliyet/Fitness = 0.0493
# Parçacık 6: Pozisyon = -0.5947, Hız = 6.1517, Maliyet/Fitness = 0.3537
# Parçacık 7: Pozisyon = -0.4474, Hız = -0.4884, Maliyet/Fitness = 0.2001
# Parçacık 8: Pozisyon = 1.6657, Hız = 8.8168, Maliyet/Fitness = 2.7746
# Parçacık 9: Pozisyon = 1.9116, Hız = -0.2575, Maliyet/Fitness = 3.6541
# Parçacık 10: Pozisyon = -0.6520, Hız = -7.3875, Maliyet/Fitness = 0.4251
# pbest: [7.0074, 3.5314, 0.3112, 42.7859, 0.0493, 0.3537, 0.0017, 2.7746, 3.6541, 0.4251]
# gbest: 0.0016857630194605736
#
# --- Iterasyon 2 ---
# Parçacık 1: Pozisyon = -3.4710, Hız = -6.1181, Maliyet/Fitness = 12.0478
# Parçacık 2: Pozisyon = 3.7994, Hız = 1.9202, Maliyet/Fitness = 14.4354
# Parçacık 3: Pozisyon = 4.1857, Hız = 3.6279, Maliyet/Fitness = 17.5203
# Parçacık 4: Pozisyon = 2.1713, Hız = 8.7124, Maliyet/Fitness = 4.7146
# Parçacık 5: Pozisyon = -2.2962, Hız = -2.5181, Maliyet/Fitness = 5.2723
# Parçacık 6: Pozisyon = 2.9511, Hız = 3.5458, Maliyet/Fitness = 8.7088
# Parçacık 7: Pozisyon = 0.1506, Hız = 0.5979, Maliyet/Fitness = 0.0227
# Parçacık 8: Pozisyon = 4.5843, Hız = 2.9186, Maliyet/Fitness = 21.0154
# Parçacık 9: Pozisyon = 0.9550, Hız = -0.9566, Maliyet/Fitness = 0.9119
# Parçacık 10: Pozisyon = -4.2493, Hız = -3.5974, Maliyet/Fitness = 18.0569
# pbest: [7.0074, 3.5314, 0.3112, 4.7146, 0.0493, 0.3537, 0.0017, 2.7746, 0.9119, 0.4251]
# gbest: 0.0016857630194605736
#
# --- Iterasyon 3 ---
# Parçacık 1: Pozisyon = -0.0873, Hız = 3.3837, Maliyet/Fitness = 0.0076
# Parçacık 2: Pozisyon = 3.1996, Hız = -0.5998, Maliyet/Fitness = 10.2377
# Parçacık 3: Pozisyon = 0.4995, Hız = -3.6862, Maliyet/Fitness = 0.2495
# Parçacık 4: Pozisyon = 5.4137, Hız = 3.2424, Maliyet/Fitness = 29.3080
# Parçacık 5: Pozisyon = -3.0087, Hız = -0.7125, Maliyet/Fitness = 9.0520
# Parçacık 6: Pozisyon = 1.1730, Hız = -1.7781, Maliyet/Fitness = 1.3759
# Parçacık 7: Pozisyon = 0.2138, Hız = 0.0632, Maliyet/Fitness = 0.0457
# Parçacık 8: Pozisyon = 3.5537, Hız = -1.0305, Maliyet/Fitness = 12.6290
# Parçacık 9: Pozisyon = 0.3387, Hız = -0.6163, Maliyet/Fitness = 0.1147
# Parçacık 10: Pozisyon = -0.1603, Hız = 4.0890, Maliyet/Fitness = 0.0257
# pbest: [0.0076, 3.5314, 0.2495, 4.7146, 0.0493, 0.3537, 0.0017, 2.7746, 0.1147, 0.0257]
# gbest: 0.0016857630194605736
#
# --- Iterasyon 4 ---
# Parçacık 1: Pozisyon = 1.7093, Hız = 1.7965, Maliyet/Fitness = 2.9216
# Parçacık 2: Pozisyon = 2.1897, Hız = -1.0099, Maliyet/Fitness = 4.7949
# Parçacık 3: Pozisyon = -1.4699, Hız = -1.9694, Maliyet/Fitness = 2.1605
# Parçacık 4: Pozisyon = -3.3294, Hız = -8.7431, Maliyet/Fitness = 11.0848
# Parçacık 5: Pozisyon = 0.3689, Hız = 3.3775, Maliyet/Fitness = 0.1361
# Parçacık 6: Pozisyon = -1.7657, Hız = -2.9387, Maliyet/Fitness = 3.1177
# Parçacık 7: Pozisyon = -0.0859, Hız = -0.2997, Maliyet/Fitness = 0.0074
# Parçacık 8: Pozisyon = -1.0488, Hız = -4.6025, Maliyet/Fitness = 1.1000
# Parçacık 9: Pozisyon = -0.1654, Hız = -0.5041, Maliyet/Fitness = 0.0274
# Parçacık 10: Pozisyon = 1.9425, Hız = 2.1028, Maliyet/Fitness = 3.7733
# pbest: [0.0076, 3.5314, 0.2495, 4.7146, 0.0493, 0.3537, 0.0017, 1.1, 0.0274, 0.0257]
# gbest: 0.0016857630194605736
#
# --- Iterasyon 5 ---
# Parçacık 1: Pozisyon = 1.0868, Hız = -0.6225, Maliyet/Fitness = 1.1811
# Parçacık 2: Pozisyon = 0.1566, Hız = -2.0331, Maliyet/Fitness = 0.0245
# Parçacık 3: Pozisyon = 0.1315, Hız = 1.6014, Maliyet/Fitness = 0.0173
# Parçacık 4: Pozisyon = 1.2763, Hız = 4.6057, Maliyet/Fitness = 1.6290
# Parçacık 5: Pozisyon = 1.9113, Hız = 1.5424, Maliyet/Fitness = 3.6530
# Parçacık 6: Pozisyon = -1.6376, Hız = 0.1281, Maliyet/Fitness = 2.6817
# Parçacık 7: Pozisyon = 0.0064, Hız = 0.0923, Maliyet/Fitness = 0.0000
# Parçacık 8: Pozisyon = -2.1447, Hız = -1.0959, Maliyet/Fitness = 4.5999
# Parçacık 9: Pozisyon = -0.4097, Hız = -0.2443, Maliyet/Fitness = 0.1679
# Parçacık 10: Pozisyon = 0.3860, Hız = -1.5565, Maliyet/Fitness = 0.1490
# pbest: [0.0076, 0.0245, 0.0173, 1.629, 0.0493, 0.3537, 0.0, 1.1, 0.0274, 0.0257]
# gbest: [4.06730591e-05]
#
# --- Iterasyon 6 ---
# Parçacık 1: Pozisyon = -0.2878, Hız = -1.3746, Maliyet/Fitness = 0.0828
# Parçacık 2: Pozisyon = -1.0198, Hız = -1.1764, Maliyet/Fitness = 1.0400
# Parçacık 3: Pozisyon = 0.8070, Hız = 0.6755, Maliyet/Fitness = 0.6512
# Parçacık 4: Pozisyon = 1.9812, Hız = 0.7048, Maliyet/Fitness = 3.9250
# Parçacık 5: Pozisyon = 0.0596, Hız = -1.8517, Maliyet/Fitness = 0.0036
# Parçacık 6: Pozisyon = 0.2687, Hız = 1.9063, Maliyet/Fitness = 0.0722
# Parçacık 7: Pozisyon = 0.0525, Hız = 0.0462, Maliyet/Fitness = 0.0028
# Parçacık 8: Pozisyon = -0.8516, Hız = 1.2931, Maliyet/Fitness = 0.7253
# Parçacık 9: Pozisyon = -0.2171, Hız = 0.1927, Maliyet/Fitness = 0.0471
# Parçacık 10: Pozisyon = -0.8856, Hız = -1.2716, Maliyet/Fitness = 0.7843
# pbest: [0.0076, 0.0245, 0.0173, 1.629, 0.0036, 0.0722, 0.0, 0.7253, 0.0274, 0.0257]
# gbest: [4.06730591e-05]
#
# --- Iterasyon 7 ---
# Parçacık 1: Pozisyon = -0.7170, Hız = -0.4292, Maliyet/Fitness = 0.5141
# Parçacık 2: Pozisyon = -0.6162, Hız = 0.4036, Maliyet/Fitness = 0.3797
# Parçacık 3: Pozisyon = 0.0397, Hız = -0.7673, Maliyet/Fitness = 0.0016
# Parçacık 4: Pozisyon = 0.9301, Hız = -1.0511, Maliyet/Fitness = 0.8650
# Parçacık 5: Pozisyon = -0.8767, Hız = -0.9364, Maliyet/Fitness = 0.7686
# Parçacık 6: Pozisyon = 1.2187, Hız = 0.9500, Maliyet/Fitness = 1.4853
# Parçacık 7: Pozisyon = 0.0220, Hız = -0.0306, Maliyet/Fitness = 0.0005
# Parçacık 8: Pozisyon = -0.1063, Hız = 0.7454, Maliyet/Fitness = 0.0113
# Parçacık 9: Pozisyon = 0.1488, Hız = 0.3658, Maliyet/Fitness = 0.0221
# Parçacık 10: Pozisyon = -0.6776, Hız = 0.2080, Maliyet/Fitness = 0.4592
# pbest: [0.0076, 0.0245, 0.0016, 0.865, 0.0036, 0.0722, 0.0, 0.0113, 0.0221, 0.0257]
# gbest: [4.06730591e-05]
#
# --- Iterasyon 8 ---
# Parçacık 1: Pozisyon = -0.0953, Hız = 0.6217, Maliyet/Fitness = 0.0091
# Parçacık 2: Pozisyon = 0.5951, Hız = 1.2113, Maliyet/Fitness = 0.3542
# Parçacık 3: Pozisyon = -0.3553, Hız = -0.3950, Maliyet/Fitness = 0.1262
# Parçacık 4: Pozisyon = -0.8122, Hız = -1.7423, Maliyet/Fitness = 0.6597
# Parçacık 5: Pozisyon = -0.6548, Hız = 0.2219, Maliyet/Fitness = 0.4288
# Parçacık 6: Pozisyon = -0.6829, Hız = -1.9017, Maliyet/Fitness = 0.4664
# Parçacık 7: Pozisyon = -0.0045, Hız = -0.0265, Maliyet/Fitness = 0.0000
# Parçacık 8: Pozisyon = 0.3826, Hız = 0.4889, Maliyet/Fitness = 0.1464
# Parçacık 9: Pozisyon = 0.2535, Hız = 0.1047, Maliyet/Fitness = 0.0643
# Parçacık 10: Pozisyon = 0.6205, Hız = 1.2981, Maliyet/Fitness = 0.3850
# pbest: [0.0076, 0.0245, 0.0016, 0.6597, 0.0036, 0.0722, 0.0, 0.0113, 0.0221, 0.0257]
# gbest: [2.01582394e-05]
#
# --- Iterasyon 9 ---
# Parçacık 1: Pozisyon = 0.2192, Hız = 0.3144, Maliyet/Fitness = 0.0480
# Parçacık 2: Pozisyon = 0.5398, Hız = -0.0553, Maliyet/Fitness = 0.2914
# Parçacık 3: Pozisyon = -0.0047, Hız = 0.3506, Maliyet/Fitness = 0.0000
# Parçacık 4: Pozisyon = -1.2476, Hız = -0.4354, Maliyet/Fitness = 1.5566
# Parçacık 5: Pozisyon = 0.5998, Hız = 1.2547, Maliyet/Fitness = 0.3598
# Parçacık 6: Pozisyon = -0.4978, Hız = 0.1851, Maliyet/Fitness = 0.2478
# Parçacık 7: Pozisyon = -0.0177, Hız = -0.0132, Maliyet/Fitness = 0.0003
# Parçacık 8: Pozisyon = -0.0741, Hız = -0.4567, Maliyet/Fitness = 0.0055
# Parçacık 9: Pozisyon = 0.1366, Hız = -0.1169, Maliyet/Fitness = 0.0187
# Parçacık 10: Pozisyon = 0.0593, Hız = -0.5612, Maliyet/Fitness = 0.0035
# pbest: [0.0076, 0.0245, 0.0, 0.6597, 0.0036, 0.0722, 0.0, 0.0055, 0.0187, 0.0035]
# gbest: [2.01582394e-05]
#
# --- Iterasyon 10 ---
# Parçacık 1: Pozisyon = -0.0470, Hız = -0.2661, Maliyet/Fitness = 0.0022
# Parçacık 2: Pozisyon = -0.3610, Hız = -0.9009, Maliyet/Fitness = 0.1303
# Parçacık 3: Pozisyon = 0.1581, Hız = 0.1628, Maliyet/Fitness = 0.0250
# Parçacık 4: Pozisyon = 0.5994, Hız = 1.8470, Maliyet/Fitness = 0.3592
# Parçacık 5: Pozisyon = 0.0085, Hız = -0.5913, Maliyet/Fitness = 0.0001
# Parçacık 6: Pozisyon = 0.0689, Hız = 0.5668, Maliyet/Fitness = 0.0047
# Parçacık 7: Pozisyon = -0.0165, Hız = 0.0012, Maliyet/Fitness = 0.0003
# Parçacık 8: Pozisyon = -0.2218, Hız = -0.1478, Maliyet/Fitness = 0.0492
# Parçacık 9: Pozisyon = -0.0994, Hız = -0.2360, Maliyet/Fitness = 0.0099
# Parçacık 10: Pozisyon = -0.2778, Hız = -0.3371, Maliyet/Fitness = 0.0772
# pbest: [0.0022, 0.0245, 0.0, 0.3592, 0.0001, 0.0047, 0.0, 0.0055, 0.0099, 0.0035]
# gbest: [2.01582394e-05]
#
# Global Best Pozisyon: [-0.01650238]
# Global Best : [2.01582394e-05]
