# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtalas/SezgiselOtimizasyonDersNotlari/blob/main/DE_x2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametreler
pop_size = 5      # Popülasyon boyutu
dimensions = 1      # Boyut (burada tek değişkenli)
mutation_factor = 0.8
crossover_rate = 0.7
iterations = 10    # İterasyon sayısı

# Hedef fonksiyon: x^2
def objective_function(x):
    return x[0] ** 2

# Başlangıç popülasyonu oluştur
population = np.random.uniform(-10, 10, (pop_size, dimensions))

# Her iterasyonda işlemleri ekrana yazdır
for i in range(iterations):
    print(f"\nIteration {i + 1}")
    new_population = np.copy(population)
    print(f"Populasyon: {new_population}")
    print("\n")
    for j in range(pop_size):
        # Üç rastgele farklı birey seç
        indices = np.random.choice(pop_size, 3, replace=False)
        while j in indices:
            indices = np.random.choice(pop_size, 3, replace=False)
        print("İşlem yapılan birey ",population[j])
        a, b, c = population[indices]
        mutant = a + mutation_factor * (b - c)
        print("Rastgele seçilen 3 birey : ", a ," ",b,"  ", c )
        # Mutasyon ve çaprazlama
        print("Mutasyon Sonucu : ",mutant)

        trial = np.copy(population[j])
        rn = np.random.rand()
        print("Random Sayı : ", rn ,"  CR : ", crossover_rate )
        if rn < crossover_rate:
            trial[0] = mutant[0]

        # Değerlendirme
        if objective_function(trial) < objective_function(population[j]):
            new_population[j] = trial
            print("Çocuk popülasyona devam ediyor")
        else:
            print("Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.")

        # Hesaplamaları yazdır
        print(f"Birey  {j + 1}: Xi = {population[j][0]:.4f}, Çocuk = {trial[0]:.4f}, "
              f" Mevcut Fitness= {objective_function(population[j]):.4f}, "
              f" Çocuk Fitness = {objective_function(trial):.4f}")
        print("\n\n")

    # Popülasyonu güncelle
    population = new_population



# Sonuç
best_individual = min(population, key=objective_function)
print("\nBest solution found:", best_individual[0])
print("Objective value:", objective_function(best_individual))
# Out:
# Iteration 1
# Populasyon: [[-3.54582602]
#  [ 1.74347102]
#  [-3.61811246]
#  [ 3.92699573]
#  [-5.5025712 ]]
#
#
# İşlem yapılan birey  [-3.54582602]
# Rastgele seçilen 3 birey :  [3.92699573]   [-3.61811246]    [1.74347102]
# Mutasyon Sonucu :  [-0.36227106]
# Random Sayı :  0.37026366322641047   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  1: Xi = -3.5458, Çocuk = -0.3623,  Mevcut Fitness= 12.5729,  Çocuk Fitness = 0.1312
#
#
#
# İşlem yapılan birey  [1.74347102]
# Rastgele seçilen 3 birey :  [-5.5025712]   [-3.54582602]    [-3.61811246]
# Mutasyon Sonucu :  [-5.44474205]
# Random Sayı :  0.19897782749652115   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = 1.7435, Çocuk = -5.4447,  Mevcut Fitness= 3.0397,  Çocuk Fitness = 29.6452
#
#
#
# İşlem yapılan birey  [-3.61811246]
# Rastgele seçilen 3 birey :  [1.74347102]   [-3.54582602]    [3.92699573]
# Mutasyon Sonucu :  [-4.23478637]
# Random Sayı :  0.9126256435375568   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  3: Xi = -3.6181, Çocuk = -3.6181,  Mevcut Fitness= 13.0907,  Çocuk Fitness = 13.0907
#
#
#
# İşlem yapılan birey  [3.92699573]
# Rastgele seçilen 3 birey :  [-5.5025712]   [-3.61811246]    [-3.54582602]
# Mutasyon Sonucu :  [-5.56040035]
# Random Sayı :  0.880929608751419   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  4: Xi = 3.9270, Çocuk = 3.9270,  Mevcut Fitness= 15.4213,  Çocuk Fitness = 15.4213
#
#
#
# İşlem yapılan birey  [-5.5025712]
# Rastgele seçilen 3 birey :  [-3.61811246]   [1.74347102]    [-3.54582602]
# Mutasyon Sonucu :  [0.61332518]
# Random Sayı :  0.750341836765176   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  5: Xi = -5.5026, Çocuk = -5.5026,  Mevcut Fitness= 30.2783,  Çocuk Fitness = 30.2783
#
#
#
#
# Iteration 2
# Populasyon: [[-0.36227106]
#  [ 1.74347102]
#  [-3.61811246]
#  [ 3.92699573]
#  [-5.5025712 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [3.92699573]   [1.74347102]    [-3.61811246]
# Mutasyon Sonucu :  [8.21626251]
# Random Sayı :  0.8500652379192599   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = -0.3623,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 0.1312
#
#
#
# İşlem yapılan birey  [1.74347102]
# Rastgele seçilen 3 birey :  [-0.36227106]   [-3.61811246]    [3.92699573]
# Mutasyon Sonucu :  [-6.3983576]
# Random Sayı :  0.44524308422396097   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = 1.7435, Çocuk = -6.3984,  Mevcut Fitness= 3.0397,  Çocuk Fitness = 40.9390
#
#
#
# İşlem yapılan birey  [-3.61811246]
# Rastgele seçilen 3 birey :  [3.92699573]   [-0.36227106]    [-5.5025712]
# Mutasyon Sonucu :  [8.03923584]
# Random Sayı :  0.2910930467717441   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  3: Xi = -3.6181, Çocuk = 8.0392,  Mevcut Fitness= 13.0907,  Çocuk Fitness = 64.6293
#
#
#
# İşlem yapılan birey  [3.92699573]
# Rastgele seçilen 3 birey :  [1.74347102]   [-3.61811246]    [-5.5025712]
# Mutasyon Sonucu :  [3.25103802]
# Random Sayı :  0.8490320920844451   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  4: Xi = 3.9270, Çocuk = 3.9270,  Mevcut Fitness= 15.4213,  Çocuk Fitness = 15.4213
#
#
#
# İşlem yapılan birey  [-5.5025712]
# Rastgele seçilen 3 birey :  [3.92699573]   [1.74347102]    [-3.61811246]
# Mutasyon Sonucu :  [8.21626251]
# Random Sayı :  0.9018229276408753   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  5: Xi = -5.5026, Çocuk = -5.5026,  Mevcut Fitness= 30.2783,  Çocuk Fitness = 30.2783
#
#
#
#
# Iteration 3
# Populasyon: [[-0.36227106]
#  [ 1.74347102]
#  [-3.61811246]
#  [ 3.92699573]
#  [-5.5025712 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [-3.61811246]   [3.92699573]    [1.74347102]
# Mutasyon Sonucu :  [-1.87129269]
# Random Sayı :  0.1256157802931901   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = -1.8713,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 3.5017
#
#
#
# İşlem yapılan birey  [1.74347102]
# Rastgele seçilen 3 birey :  [3.92699573]   [-0.36227106]    [-3.61811246]
# Mutasyon Sonucu :  [6.53166885]
# Random Sayı :  0.1467627305356881   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = 1.7435, Çocuk = 6.5317,  Mevcut Fitness= 3.0397,  Çocuk Fitness = 42.6627
#
#
#
# İşlem yapılan birey  [-3.61811246]
# Rastgele seçilen 3 birey :  [-5.5025712]   [3.92699573]    [1.74347102]
# Mutasyon Sonucu :  [-3.75575144]
# Random Sayı :  0.8596966990978419   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  3: Xi = -3.6181, Çocuk = -3.6181,  Mevcut Fitness= 13.0907,  Çocuk Fitness = 13.0907
#
#
#
# İşlem yapılan birey  [3.92699573]
# Rastgele seçilen 3 birey :  [-3.61811246]   [-5.5025712]    [-0.36227106]
# Mutasyon Sonucu :  [-7.73035257]
# Random Sayı :  0.4916971946323089   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  4: Xi = 3.9270, Çocuk = -7.7304,  Mevcut Fitness= 15.4213,  Çocuk Fitness = 59.7584
#
#
#
# İşlem yapılan birey  [-5.5025712]
# Rastgele seçilen 3 birey :  [-3.61811246]   [1.74347102]    [3.92699573]
# Mutasyon Sonucu :  [-5.36493222]
# Random Sayı :  0.26800005839899566   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  5: Xi = -5.5026, Çocuk = -5.3649,  Mevcut Fitness= 30.2783,  Çocuk Fitness = 28.7825
#
#
#
#
# Iteration 4
# Populasyon: [[-0.36227106]
#  [ 1.74347102]
#  [-3.61811246]
#  [ 3.92699573]
#  [-5.36493222]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [3.92699573]   [1.74347102]    [-5.36493222]
# Mutasyon Sonucu :  [9.61371832]
# Random Sayı :  0.028620953852055875   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = 9.6137,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 92.4236
#
#
#
# İşlem yapılan birey  [1.74347102]
# Rastgele seçilen 3 birey :  [3.92699573]   [-5.36493222]    [-0.36227106]
# Mutasyon Sonucu :  [-0.0751332]
# Random Sayı :  0.1144305590630752   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  2: Xi = 1.7435, Çocuk = -0.0751,  Mevcut Fitness= 3.0397,  Çocuk Fitness = 0.0056
#
#
#
# İşlem yapılan birey  [-3.61811246]
# Rastgele seçilen 3 birey :  [3.92699573]   [-5.36493222]    [1.74347102]
# Mutasyon Sonucu :  [-1.75972687]
# Random Sayı :  0.792009925912608   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  3: Xi = -3.6181, Çocuk = -3.6181,  Mevcut Fitness= 13.0907,  Çocuk Fitness = 13.0907
#
#
#
# İşlem yapılan birey  [3.92699573]
# Rastgele seçilen 3 birey :  [1.74347102]   [-5.36493222]    [-0.36227106]
# Mutasyon Sonucu :  [-2.25865791]
# Random Sayı :  0.15993673209308912   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  4: Xi = 3.9270, Çocuk = -2.2587,  Mevcut Fitness= 15.4213,  Çocuk Fitness = 5.1015
#
#
#
# İşlem yapılan birey  [-5.36493222]
# Rastgele seçilen 3 birey :  [1.74347102]   [-0.36227106]    [3.92699573]
# Mutasyon Sonucu :  [-1.6879424]
# Random Sayı :  0.050546696855815365   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  5: Xi = -5.3649, Çocuk = -1.6879,  Mevcut Fitness= 28.7825,  Çocuk Fitness = 2.8491
#
#
#
#
# Iteration 5
# Populasyon: [[-0.36227106]
#  [-0.0751332 ]
#  [-3.61811246]
#  [-2.25865791]
#  [-1.6879424 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [-2.25865791]   [-1.6879424]    [-0.0751332]
# Mutasyon Sonucu :  [-3.54890527]
# Random Sayı :  0.21460273869918056   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = -3.5489,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 12.5947
#
#
#
# İşlem yapılan birey  [-0.0751332]
# Rastgele seçilen 3 birey :  [-3.61811246]   [-1.6879424]    [-2.25865791]
# Mutasyon Sonucu :  [-3.16154005]
# Random Sayı :  0.6165382784494182   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = -0.0751, Çocuk = -3.1615,  Mevcut Fitness= 0.0056,  Çocuk Fitness = 9.9953
#
#
#
# İşlem yapılan birey  [-3.61811246]
# Rastgele seçilen 3 birey :  [-2.25865791]   [-0.0751332]    [-0.36227106]
# Mutasyon Sonucu :  [-2.02894762]
# Random Sayı :  0.9134095248888544   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  3: Xi = -3.6181, Çocuk = -3.6181,  Mevcut Fitness= 13.0907,  Çocuk Fitness = 13.0907
#
#
#
# İşlem yapılan birey  [-2.25865791]
# Rastgele seçilen 3 birey :  [-0.36227106]   [-1.6879424]    [-0.0751332]
# Mutasyon Sonucu :  [-1.65251842]
# Random Sayı :  0.5345429418064144   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  4: Xi = -2.2587, Çocuk = -1.6525,  Mevcut Fitness= 5.1015,  Çocuk Fitness = 2.7308
#
#
#
# İşlem yapılan birey  [-1.6879424]
# Rastgele seçilen 3 birey :  [-3.61811246]   [-0.36227106]    [-2.25865791]
# Mutasyon Sonucu :  [-2.10100298]
# Random Sayı :  0.35011084348502297   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  5: Xi = -1.6879, Çocuk = -2.1010,  Mevcut Fitness= 2.8491,  Çocuk Fitness = 4.4142
#
#
#
#
# Iteration 6
# Populasyon: [[-0.36227106]
#  [-0.0751332 ]
#  [-3.61811246]
#  [-1.65251842]
#  [-1.6879424 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [-1.6879424]   [-3.61811246]    [-0.0751332]
# Mutasyon Sonucu :  [-4.52232581]
# Random Sayı :  0.32471543529906377   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = -4.5223,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 20.4514
#
#
#
# İşlem yapılan birey  [-0.0751332]
# Rastgele seçilen 3 birey :  [-3.61811246]   [-1.6879424]    [-0.36227106]
# Mutasyon Sonucu :  [-4.67864953]
# Random Sayı :  0.5612972505794834   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = -0.0751, Çocuk = -4.6786,  Mevcut Fitness= 0.0056,  Çocuk Fitness = 21.8898
#
#
#
# İşlem yapılan birey  [-3.61811246]
# Rastgele seçilen 3 birey :  [-1.65251842]   [-1.6879424]    [-0.36227106]
# Mutasyon Sonucu :  [-2.71305549]
# Random Sayı :  0.5422317539702726   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  3: Xi = -3.6181, Çocuk = -2.7131,  Mevcut Fitness= 13.0907,  Çocuk Fitness = 7.3607
#
#
#
# İşlem yapılan birey  [-1.65251842]
# Rastgele seçilen 3 birey :  [-1.6879424]   [-3.61811246]    [-0.0751332]
# Mutasyon Sonucu :  [-4.52232581]
# Random Sayı :  0.6287959593911555   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  4: Xi = -1.6525, Çocuk = -4.5223,  Mevcut Fitness= 2.7308,  Çocuk Fitness = 20.4514
#
#
#
# İşlem yapılan birey  [-1.6879424]
# Rastgele seçilen 3 birey :  [-1.65251842]   [-0.36227106]    [-3.61811246]
# Mutasyon Sonucu :  [0.9521547]
# Random Sayı :  0.3558674684190666   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  5: Xi = -1.6879, Çocuk = 0.9522,  Mevcut Fitness= 2.8491,  Çocuk Fitness = 0.9066
#
#
#
#
# Iteration 7
# Populasyon: [[-0.36227106]
#  [-0.0751332 ]
#  [-2.71305549]
#  [-1.65251842]
#  [ 0.9521547 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [-0.0751332]   [-1.65251842]    [-2.71305549]
# Mutasyon Sonucu :  [0.77329646]
# Random Sayı :  0.8515714945303154   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = -0.3623,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 0.1312
#
#
#
# İşlem yapılan birey  [-0.0751332]
# Rastgele seçilen 3 birey :  [0.9521547]   [-2.71305549]    [-0.36227106]
# Mutasyon Sonucu :  [-0.92847285]
# Random Sayı :  0.9374086072732122   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = -0.0751, Çocuk = -0.0751,  Mevcut Fitness= 0.0056,  Çocuk Fitness = 0.0056
#
#
#
# İşlem yapılan birey  [-2.71305549]
# Rastgele seçilen 3 birey :  [-1.65251842]   [-0.36227106]    [-0.0751332]
# Mutasyon Sonucu :  [-1.8822287]
# Random Sayı :  0.16742092896477612   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  3: Xi = -2.7131, Çocuk = -1.8822,  Mevcut Fitness= 7.3607,  Çocuk Fitness = 3.5428
#
#
#
# İşlem yapılan birey  [-1.65251842]
# Rastgele seçilen 3 birey :  [-0.36227106]   [-0.0751332]    [0.9521547]
# Mutasyon Sonucu :  [-1.18410138]
# Random Sayı :  0.9086376403153179   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  4: Xi = -1.6525, Çocuk = -1.6525,  Mevcut Fitness= 2.7308,  Çocuk Fitness = 2.7308
#
#
#
# İşlem yapılan birey  [0.9521547]
# Rastgele seçilen 3 birey :  [-0.36227106]   [-1.65251842]    [-0.0751332]
# Mutasyon Sonucu :  [-1.62417923]
# Random Sayı :  0.3031628686230323   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  5: Xi = 0.9522, Çocuk = -1.6242,  Mevcut Fitness= 0.9066,  Çocuk Fitness = 2.6380
#
#
#
#
# Iteration 8
# Populasyon: [[-0.36227106]
#  [-0.0751332 ]
#  [-1.8822287 ]
#  [-1.65251842]
#  [ 0.9521547 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [-0.0751332]   [0.9521547]    [-1.65251842]
# Mutasyon Sonucu :  [2.00860529]
# Random Sayı :  0.6288186891030215   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = 2.0086,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 4.0345
#
#
#
# İşlem yapılan birey  [-0.0751332]
# Rastgele seçilen 3 birey :  [-0.36227106]   [-1.8822287]    [0.9521547]
# Mutasyon Sonucu :  [-2.62977778]
# Random Sayı :  0.1621390713594445   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = -0.0751, Çocuk = -2.6298,  Mevcut Fitness= 0.0056,  Çocuk Fitness = 6.9157
#
#
#
# İşlem yapılan birey  [-1.8822287]
# Rastgele seçilen 3 birey :  [-0.0751332]   [-1.65251842]    [0.9521547]
# Mutasyon Sonucu :  [-2.1588717]
# Random Sayı :  0.8443169804721701   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  3: Xi = -1.8822, Çocuk = -1.8822,  Mevcut Fitness= 3.5428,  Çocuk Fitness = 3.5428
#
#
#
# İşlem yapılan birey  [-1.65251842]
# Rastgele seçilen 3 birey :  [-1.8822287]   [0.9521547]    [-0.0751332]
# Mutasyon Sonucu :  [-1.06039838]
# Random Sayı :  0.20226527097858638   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  4: Xi = -1.6525, Çocuk = -1.0604,  Mevcut Fitness= 2.7308,  Çocuk Fitness = 1.1244
#
#
#
# İşlem yapılan birey  [0.9521547]
# Rastgele seçilen 3 birey :  [-1.65251842]   [-0.36227106]    [-1.8822287]
# Mutasyon Sonucu :  [-0.4365523]
# Random Sayı :  0.6311444645202933   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  5: Xi = 0.9522, Çocuk = -0.4366,  Mevcut Fitness= 0.9066,  Çocuk Fitness = 0.1906
#
#
#
#
# Iteration 9
# Populasyon: [[-0.36227106]
#  [-0.0751332 ]
#  [-1.8822287 ]
#  [-1.06039838]
#  [-0.4365523 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [-0.0751332]   [-1.06039838]    [-1.8822287]
# Mutasyon Sonucu :  [0.58233106]
# Random Sayı :  0.2655522790111565   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = 0.5823,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 0.3391
#
#
#
# İşlem yapılan birey  [-0.0751332]
# Rastgele seçilen 3 birey :  [-1.06039838]   [-0.36227106]    [-0.4365523]
# Mutasyon Sonucu :  [-1.00097338]
# Random Sayı :  0.7580172483332857   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = -0.0751, Çocuk = -0.0751,  Mevcut Fitness= 0.0056,  Çocuk Fitness = 0.0056
#
#
#
# İşlem yapılan birey  [-1.8822287]
# Rastgele seçilen 3 birey :  [-1.06039838]   [-0.36227106]    [-0.4365523]
# Mutasyon Sonucu :  [-1.00097338]
# Random Sayı :  0.04814540036898074   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  3: Xi = -1.8822, Çocuk = -1.0010,  Mevcut Fitness= 3.5428,  Çocuk Fitness = 1.0019
#
#
#
# İşlem yapılan birey  [-1.06039838]
# Rastgele seçilen 3 birey :  [-0.4365523]   [-0.36227106]    [-1.8822287]
# Mutasyon Sonucu :  [0.77941381]
# Random Sayı :  0.980136385671844   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  4: Xi = -1.0604, Çocuk = -1.0604,  Mevcut Fitness= 1.1244,  Çocuk Fitness = 1.1244
#
#
#
# İşlem yapılan birey  [-0.4365523]
# Rastgele seçilen 3 birey :  [-1.06039838]   [-1.8822287]    [-0.36227106]
# Mutasyon Sonucu :  [-2.27636449]
# Random Sayı :  0.6087206151416925   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  5: Xi = -0.4366, Çocuk = -2.2764,  Mevcut Fitness= 0.1906,  Çocuk Fitness = 5.1818
#
#
#
#
# Iteration 10
# Populasyon: [[-0.36227106]
#  [-0.0751332 ]
#  [-1.00097338]
#  [-1.06039838]
#  [-0.4365523 ]]
#
#
# İşlem yapılan birey  [-0.36227106]
# Rastgele seçilen 3 birey :  [-0.4365523]   [-1.00097338]    [-0.0751332]
# Mutasyon Sonucu :  [-1.17722444]
# Random Sayı :  0.7615225090108191   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  1: Xi = -0.3623, Çocuk = -0.3623,  Mevcut Fitness= 0.1312,  Çocuk Fitness = 0.1312
#
#
#
# İşlem yapılan birey  [-0.0751332]
# Rastgele seçilen 3 birey :  [-1.06039838]   [-1.00097338]    [-0.4365523]
# Mutasyon Sonucu :  [-1.51193524]
# Random Sayı :  0.3698535391507368   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  2: Xi = -0.0751, Çocuk = -1.5119,  Mevcut Fitness= 0.0056,  Çocuk Fitness = 2.2859
#
#
#
# İşlem yapılan birey  [-1.00097338]
# Rastgele seçilen 3 birey :  [-1.06039838]   [-0.4365523]    [-0.36227106]
# Mutasyon Sonucu :  [-1.11982337]
# Random Sayı :  0.349953476919755   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  3: Xi = -1.0010, Çocuk = -1.1198,  Mevcut Fitness= 1.0019,  Çocuk Fitness = 1.2540
#
#
#
# İşlem yapılan birey  [-1.06039838]
# Rastgele seçilen 3 birey :  [-1.00097338]   [-0.0751332]    [-0.36227106]
# Mutasyon Sonucu :  [-0.7712631]
# Random Sayı :  0.4078695644145982   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey  4: Xi = -1.0604, Çocuk = -0.7713,  Mevcut Fitness= 1.1244,  Çocuk Fitness = 0.5948
#
#
#
# İşlem yapılan birey  [-0.4365523]
# Rastgele seçilen 3 birey :  [-0.0751332]   [-0.36227106]    [-1.06039838]
# Mutasyon Sonucu :  [0.48336865]
# Random Sayı :  0.3906233876141517   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey  5: Xi = -0.4366, Çocuk = 0.4834,  Mevcut Fitness= 0.1906,  Çocuk Fitness = 0.2336
#
#
#
#
# Best solution found: -0.07513320307060578
# Objective value: 0.005644998203648886
