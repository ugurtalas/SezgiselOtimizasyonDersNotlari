# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtalas/SezgiselOtimizasyonDersNotlari/blob/main/DE_x2y2V2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Parametreler
pop_size = 5       # Popülasyon boyutu
dimensions = 2     # Boyut (2D olarak güncellendi)
mutation_factor = 0.8
crossover_rate = 0.7
iterations = 10    # İterasyon sayısı

# Hedef fonksiyon f(x, y) = x^2 + y^2
def objective_function(x):
    return x[0] ** 2 + x[1] ** 2

# Başlangıç popülasyonu oluştur (2D)
population = np.random.uniform(-5.12, 5.12, (pop_size, dimensions))

# Her iterasyonda işlemleri ekrana yazdır ve grafiği çizdir
for i in range(iterations):
    print(f"\nIteration {i + 1}")
    new_population = np.copy(population)
    print(f"Populasyon: {new_population}")
    print("\n")

    # Bireyleri işleyin
    for j in range(pop_size):
        # Üç rastgele farklı birey seç
        indices = np.random.choice(pop_size, 3, replace=False)
        while j in indices:
            indices = np.random.choice(pop_size, 3, replace=False)
        print("İşlem yapılan birey ", population[j])
        a, b, c = population[indices]
        mutant = a + mutation_factor * (b - c)
        print("Rastgele seçilen 3 birey : xr1", a, " xr2", b, "  xr3", c )
        # Mutasyon ve çaprazlama
        print("Fark Vektörü : ", mutant)

        trial = np.copy(population[j])



        for d in range(dimensions):
          rn = np.random.rand()
          print("Rastgele Sayı : ", rn, "  Cr : ", crossover_rate)
          if rn < crossover_rate:
            trial[d] = mutant[d]

        ui = trial
        print("ui : ", ui)

        # Değerlendirme
        if objective_function(trial) < objective_function(population[j]):
            new_population[j] = trial

        # Hesaplamaları yazdır
        print(f"Birey {j + 1}: Xi = {population[j]}, ui = {trial}, "
              f" xi Fitness= {objective_function(population[j]):.4f}, "
              f" ui Fitness = {objective_function(trial):.4f}")
        print("\n\n")

    # Popülasyonu güncelle
    population = new_population

    # Grafik çizimi için hazırlık
    x_values = np.linspace(-5.12, 5.12, 100)
    y_values = np.linspace(-5.12, 5.12, 100)
    X, Y = np.meshgrid(x_values, y_values)
    Z = X ** 2 + Y ** 2  # f(x, y) = x^2 + y^2

    # Grafik çizimi
    fig = plt.figure(figsize=(18, 6))

    # 3D Surface plot
    ax1 = fig.add_subplot(131, projection='3d')
    ax1.plot_surface(X, Y, Z, cmap='viridis', edgecolor='none', alpha=0.7)
    ax1.scatter(population[:, 0], population[:, 1], [objective_function(ind) for ind in population], color='red')
    ax1.set_title(f'3D (İterasyon :  {i + 1})')
    ax1.set_xlabel('X')
    ax1.set_ylabel('Y')
    ax1.set_zlabel('Fitness')

    # Contour plot
    ax2 = fig.add_subplot(132)
    contour = ax2.contourf(X, Y, Z, levels=50, cmap='viridis')
    fig.colorbar(contour, ax=ax2)
    ax2.scatter(population[:, 0], population[:, 1], color='red', label='Birey')
    ax2.set_title(f'Tepeden Görünüm (İterasyon {i + 1})')
    ax2.set_xlabel('X')
    ax2.set_ylabel('Y')
    ax2.legend()

    # 2D Scatter plot of population on the function f(x, y) = x^2 + y^2
    ax3 = fig.add_subplot(133)
    z_values = [objective_function([x, y]) for x, y in population]
    ax3.plot(x_values, [objective_function([x, 0]) for x in x_values], label='Objective Function (1D Slice)', color='orange')
    ax3.scatter(population[:, 0], z_values, color='blue', label='Birey')
    ax3.set_title(f'Kesiti alınmış grafik (İterasyon {i + 1})')
    ax3.set_xlabel('X')
    ax3.set_ylabel('Fitness')
    ax3.legend()
    ax3.grid(True)

    plt.show()

# Sonuç
best_individual = min(population, key=objective_function)
print("\n En iyi çözüm:", best_individual)
print("En iyi fitness:", objective_function(best_individual))
# Out:
# Iteration 1
# Populasyon: [[-2.471862   -4.30521851]
#  [ 1.6693909  -3.34790286]
#  [ 0.98881984 -3.97888436]
#  [ 4.16981518  4.46110603]
#  [-3.58451359 -0.15652833]]
#
#
# İşlem yapılan birey  [-2.471862   -4.30521851]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [-3.58451359 -0.15652833]   xr3 [4.16981518 4.46110603]
# Fark Vektörü :  [-4.53407212 -7.04201035]
# Rastgele Sayı :  0.9753074054711596   Cr :  0.7
# Rastgele Sayı :  0.9594785816541432   Cr :  0.7
# ui :  [-2.471862   -4.30521851]
# Birey 1: Xi = [-2.471862   -4.30521851], ui = [-2.471862   -4.30521851],  xi Fitness= 24.6450,  ui Fitness = 24.6450
#
#
#
# İşlem yapılan birey  [ 1.6693909  -3.34790286]
# Rastgele seçilen 3 birey : xr1 [4.16981518 4.46110603]  xr2 [-2.471862   -4.30521851]   xr3 [ 0.98881984 -3.97888436]
# Fark Vektörü :  [1.40126971 4.20003871]
# Rastgele Sayı :  0.4476255373501047   Cr :  0.7
# Rastgele Sayı :  0.18465821003441119   Cr :  0.7
# ui :  [1.40126971 4.20003871]
# Birey 2: Xi = [ 1.6693909  -3.34790286], ui = [1.40126971 4.20003871],  xi Fitness= 13.9953,  ui Fitness = 19.6039
#
#
#
# İşlem yapılan birey  [ 0.98881984 -3.97888436]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [-3.58451359 -0.15652833]   xr3 [-2.471862   -4.30521851]
# Fark Vektörü :  [ 0.77926962 -0.02895072]
# Rastgele Sayı :  0.19096981188418538   Cr :  0.7
# Rastgele Sayı :  0.7701206610958753   Cr :  0.7
# ui :  [ 0.77926962 -3.97888436]
# Birey 3: Xi = [ 0.98881984 -3.97888436], ui = [ 0.77926962 -3.97888436],  xi Fitness= 16.8093,  ui Fitness = 16.4388
#
#
#
# İşlem yapılan birey  [4.16981518 4.46110603]
# Rastgele seçilen 3 birey : xr1 [-3.58451359 -0.15652833]  xr2 [-2.471862   -4.30521851]   xr3 [ 1.6693909  -3.34790286]
# Fark Vektörü :  [-6.89751591 -0.92238085]
# Rastgele Sayı :  0.5393145926132606   Cr :  0.7
# Rastgele Sayı :  0.26136898804663067   Cr :  0.7
# ui :  [-6.89751591 -0.92238085]
# Birey 4: Xi = [4.16981518 4.46110603], ui = [-6.89751591 -0.92238085],  xi Fitness= 37.2888,  ui Fitness = 48.4265
#
#
#
# İşlem yapılan birey  [-3.58451359 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [4.16981518 4.46110603]   xr3 [-2.471862   -4.30521851]
# Fark Vektörü :  [6.98273265 3.66515677]
# Rastgele Sayı :  0.7798685082698223   Cr :  0.7
# Rastgele Sayı :  0.3532898559041229   Cr :  0.7
# ui :  [-3.58451359  3.66515677]
# Birey 5: Xi = [-3.58451359 -0.15652833], ui = [-3.58451359  3.66515677],  xi Fitness= 12.8732,  ui Fitness = 26.2821
# Iteration 2
# Populasyon: [[-2.471862   -4.30521851]
#  [ 1.6693909  -3.34790286]
#  [ 0.77926962 -3.97888436]
#  [ 4.16981518  4.46110603]
#  [-3.58451359 -0.15652833]]
#
#
# İşlem yapılan birey  [-2.471862   -4.30521851]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [-3.58451359 -0.15652833]   xr3 [ 0.77926962 -3.97888436]
# Fark Vektörü :  [-1.82163567 -0.29001804]
# Rastgele Sayı :  0.2990524608482773   Cr :  0.7
# Rastgele Sayı :  0.2994143781963241   Cr :  0.7
# ui :  [-1.82163567 -0.29001804]
# Birey 1: Xi = [-2.471862   -4.30521851], ui = [-1.82163567 -0.29001804],  xi Fitness= 24.6450,  ui Fitness = 3.4025
#
#
#
# İşlem yapılan birey  [ 1.6693909  -3.34790286]
# Rastgele seçilen 3 birey : xr1 [-2.471862   -4.30521851]  xr2 [4.16981518 4.46110603]   xr3 [-3.58451359 -0.15652833]
# Fark Vektörü :  [ 3.73160102 -0.61111101]
# Rastgele Sayı :  0.5489453090678627   Cr :  0.7
# Rastgele Sayı :  0.5050006350894327   Cr :  0.7
# ui :  [ 3.73160102 -0.61111101]
# Birey 2: Xi = [ 1.6693909  -3.34790286], ui = [ 3.73160102 -0.61111101],  xi Fitness= 13.9953,  ui Fitness = 14.2983
#
#
#
# İşlem yapılan birey  [ 0.77926962 -3.97888436]
# Rastgele seçilen 3 birey : xr1 [-3.58451359 -0.15652833]  xr2 [ 1.6693909  -3.34790286]   xr3 [4.16981518 4.46110603]
# Fark Vektörü :  [-5.58485302 -6.40373545]
# Rastgele Sayı :  0.5738604939652199   Cr :  0.7
# Rastgele Sayı :  0.7490797343763568   Cr :  0.7
# ui :  [-5.58485302 -3.97888436]
# Birey 3: Xi = [ 0.77926962 -3.97888436], ui = [-5.58485302 -3.97888436],  xi Fitness= 16.4388,  ui Fitness = 47.0221
#
#
#
# İşlem yapılan birey  [4.16981518 4.46110603]
# Rastgele seçilen 3 birey : xr1 [-3.58451359 -0.15652833]  xr2 [-2.471862   -4.30521851]   xr3 [ 0.77926962 -3.97888436]
# Fark Vektörü :  [-6.18541889 -0.41759565]
# Rastgele Sayı :  0.46422682479206734   Cr :  0.7
# Rastgele Sayı :  0.573266542661728   Cr :  0.7
# ui :  [-6.18541889 -0.41759565]
# Birey 4: Xi = [4.16981518 4.46110603], ui = [-6.18541889 -0.41759565],  xi Fitness= 37.2888,  ui Fitness = 38.4338
#
#
#
# İşlem yapılan birey  [-3.58451359 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [-2.471862   -4.30521851]  xr2 [4.16981518 4.46110603]   xr3 [ 0.77926962 -3.97888436]
# Fark Vektörü :  [0.24057445 2.44677381]
# Rastgele Sayı :  0.3593014999014196   Cr :  0.7
# Rastgele Sayı :  0.7645384616774564   Cr :  0.7
# ui :  [ 0.24057445 -0.15652833]
# Birey 5: Xi = [-3.58451359 -0.15652833], ui = [ 0.24057445 -0.15652833],  xi Fitness= 12.8732,  ui Fitness = 0.0824
# Iteration 3
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909  -3.34790286]
#  [ 0.77926962 -3.97888436]
#  [ 4.16981518  4.46110603]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [ 0.77926962 -3.97888436]  xr2 [ 0.24057445 -0.15652833]   xr3 [4.16981518 4.46110603]
# Fark Vektörü :  [-2.36412296 -7.67299185]
# Rastgele Sayı :  0.8023717074566271   Cr :  0.7
# Rastgele Sayı :  0.10479793059171383   Cr :  0.7
# ui :  [-1.82163567 -7.67299185]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [-1.82163567 -7.67299185],  xi Fitness= 3.4025,  ui Fitness = 62.1932
#
#
#
# İşlem yapılan birey  [ 1.6693909  -3.34790286]
# Rastgele seçilen 3 birey : xr1 [ 0.24057445 -0.15652833]  xr2 [4.16981518 4.46110603]   xr3 [ 0.77926962 -3.97888436]
# Fark Vektörü :  [2.9530109  6.59546398]
# Rastgele Sayı :  0.9435425824536914   Cr :  0.7
# Rastgele Sayı :  0.7170602570441804   Cr :  0.7
# ui :  [ 1.6693909  -3.34790286]
# Birey 2: Xi = [ 1.6693909  -3.34790286], ui = [ 1.6693909  -3.34790286],  xi Fitness= 13.9953,  ui Fitness = 13.9953
#
#
#
# İşlem yapılan birey  [ 0.77926962 -3.97888436]
# Rastgele seçilen 3 birey : xr1 [4.16981518 4.46110603]  xr2 [-1.82163567 -0.29001804]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [2.52004709 4.35431427]
# Rastgele Sayı :  0.3131437566503298   Cr :  0.7
# Rastgele Sayı :  0.9033802409194018   Cr :  0.7
# ui :  [ 2.52004709 -3.97888436]
# Birey 3: Xi = [ 0.77926962 -3.97888436], ui = [ 2.52004709 -3.97888436],  xi Fitness= 16.4388,  ui Fitness = 22.1822
#
#
#
# İşlem yapılan birey  [4.16981518 4.46110603]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [ 0.24057445 -0.15652833]   xr3 [ 1.6693909  -3.34790286]
# Fark Vektörü :  [-2.96468884  2.26308158]
# Rastgele Sayı :  0.9441952744840977   Cr :  0.7
# Rastgele Sayı :  0.2326629889574824   Cr :  0.7
# ui :  [4.16981518 2.26308158]
# Birey 4: Xi = [4.16981518 4.46110603], ui = [4.16981518 2.26308158],  xi Fitness= 37.2888,  ui Fitness = 22.5089
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [ 0.77926962 -3.97888436]  xr2 [ 1.6693909  -3.34790286]   xr3 [4.16981518 4.46110603]
# Fark Vektörü :  [ -1.2210698  -10.22609147]
# Rastgele Sayı :  0.4586853404892772   Cr :  0.7
# Rastgele Sayı :  0.07233220739735269   Cr :  0.7
# ui :  [ -1.2210698  -10.22609147]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [ -1.2210698  -10.22609147],  xi Fitness= 0.0824,  ui Fitness = 106.0640
# Iteration 4
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909  -3.34790286]
#  [ 0.77926962 -3.97888436]
#  [ 4.16981518  2.26308158]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [ 0.77926962 -3.97888436]   xr3 [4.16981518 2.26308158]
# Fark Vektörü :  [-1.04304555 -8.34147561]
# Rastgele Sayı :  0.6150758873118805   Cr :  0.7
# Rastgele Sayı :  0.1004874557991815   Cr :  0.7
# ui :  [-1.04304555 -8.34147561]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [-1.04304555 -8.34147561],  xi Fitness= 3.4025,  ui Fitness = 70.6682
#
#
#
# İşlem yapılan birey  [ 1.6693909  -3.34790286]
# Rastgele seçilen 3 birey : xr1 [ 0.77926962 -3.97888436]  xr2 [-1.82163567 -0.29001804]   xr3 [4.16981518 2.26308158]
# Fark Vektörü :  [-4.01389106 -6.02136406]
# Rastgele Sayı :  0.0735542069650853   Cr :  0.7
# Rastgele Sayı :  0.399963851592417   Cr :  0.7
# ui :  [-4.01389106 -6.02136406]
# Birey 2: Xi = [ 1.6693909  -3.34790286], ui = [-4.01389106 -6.02136406],  xi Fitness= 13.9953,  ui Fitness = 52.3681
#
#
#
# İşlem yapılan birey  [ 0.77926962 -3.97888436]
# Rastgele seçilen 3 birey : xr1 [4.16981518 2.26308158]  xr2 [ 1.6693909  -3.34790286]   xr3 [-1.82163567 -0.29001804]
# Fark Vektörü :  [ 6.96263644 -0.18322627]
# Rastgele Sayı :  0.048080052452126876   Cr :  0.7
# Rastgele Sayı :  0.6568622668371937   Cr :  0.7
# ui :  [ 6.96263644 -0.18322627]
# Birey 3: Xi = [ 0.77926962 -3.97888436], ui = [ 6.96263644 -0.18322627],  xi Fitness= 16.4388,  ui Fitness = 48.5119
#
#
#
# İşlem yapılan birey  [4.16981518 2.26308158]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [-1.82163567 -0.29001804]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [ 0.0196228  -3.45469463]
# Rastgele Sayı :  0.8902629407963917   Cr :  0.7
# Rastgele Sayı :  0.9002207541580521   Cr :  0.7
# ui :  [4.16981518 2.26308158]
# Birey 4: Xi = [4.16981518 2.26308158], ui = [4.16981518 2.26308158],  xi Fitness= 22.5089,  ui Fitness = 22.5089
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [4.16981518 2.26308158]  xr2 [ 1.6693909  -3.34790286]   xr3 [ 0.77926962 -3.97888436]
# Fark Vektörü :  [4.8819122  2.76786678]
# Rastgele Sayı :  0.4933713920221535   Cr :  0.7
# Rastgele Sayı :  0.3555523098671348   Cr :  0.7
# ui :  [4.8819122  2.76786678]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [4.8819122  2.76786678],  xi Fitness= 0.0824,  ui Fitness = 31.4942
# Iteration 5
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909  -3.34790286]
#  [ 0.77926962 -3.97888436]
#  [ 4.16981518  2.26308158]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [ 0.24057445 -0.15652833]   xr3 [4.16981518 2.26308158]
# Fark Vektörü :  [-1.47400169 -5.28359079]
# Rastgele Sayı :  0.853962216085494   Cr :  0.7
# Rastgele Sayı :  0.28051665090265254   Cr :  0.7
# ui :  [-1.82163567 -5.28359079]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [-1.82163567 -5.28359079],  xi Fitness= 3.4025,  ui Fitness = 31.2347
#
#
#
# İşlem yapılan birey  [ 1.6693909  -3.34790286]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [ 0.77926962 -3.97888436]   xr3 [4.16981518 2.26308158]
# Fark Vektörü :  [-4.53407212 -5.28359079]
# Rastgele Sayı :  0.08662788290770707   Cr :  0.7
# Rastgele Sayı :  0.5261185003720759   Cr :  0.7
# ui :  [-4.53407212 -5.28359079]
# Birey 2: Xi = [ 1.6693909  -3.34790286], ui = [-4.53407212 -5.28359079],  xi Fitness= 13.9953,  ui Fitness = 48.4741
#
#
#
# İşlem yapılan birey  [ 0.77926962 -3.97888436]
# Rastgele seçilen 3 birey : xr1 [4.16981518 2.26308158]  xr2 [-1.82163567 -0.29001804]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [2.52004709 2.15628981]
# Rastgele Sayı :  0.135626262957522   Cr :  0.7
# Rastgele Sayı :  0.34354056657942444   Cr :  0.7
# ui :  [2.52004709 2.15628981]
# Birey 3: Xi = [ 0.77926962 -3.97888436], ui = [2.52004709 2.15628981],  xi Fitness= 16.4388,  ui Fitness = 11.0002
#
#
#
# İşlem yapılan birey  [4.16981518 2.26308158]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [ 0.77926962 -3.97888436]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [ 2.10034704 -6.40578768]
# Rastgele Sayı :  0.9676408008180402   Cr :  0.7
# Rastgele Sayı :  0.4749476080434759   Cr :  0.7
# ui :  [ 4.16981518 -6.40578768]
# Birey 4: Xi = [4.16981518 2.26308158], ui = [ 4.16981518 -6.40578768],  xi Fitness= 22.5089,  ui Fitness = 58.4215
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [4.16981518 2.26308158]   xr3 [-1.82163567 -0.29001804]
# Fark Vektörü :  [ 6.46255159 -1.30542316]
# Rastgele Sayı :  0.5002711572248113   Cr :  0.7
# Rastgele Sayı :  0.8340341901034237   Cr :  0.7
# ui :  [ 6.46255159 -0.15652833]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [ 6.46255159 -0.15652833],  xi Fitness= 0.0824,  ui Fitness = 41.7891
# Iteration 6
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909  -3.34790286]
#  [ 2.52004709  2.15628981]
#  [ 4.16981518  2.26308158]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [4.16981518 2.26308158]  xr2 [2.52004709 2.15628981]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [5.99339329 4.1133361 ]
# Rastgele Sayı :  0.5308196286100809   Cr :  0.7
# Rastgele Sayı :  0.2674530489849192   Cr :  0.7
# ui :  [5.99339329 4.1133361 ]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [5.99339329 4.1133361 ],  xi Fitness= 3.4025,  ui Fitness = 52.8403
#
#
#
# İşlem yapılan birey  [ 1.6693909  -3.34790286]
# Rastgele seçilen 3 birey : xr1 [2.52004709 2.15628981]  xr2 [4.16981518 2.26308158]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [5.66343967 4.09197774]
# Rastgele Sayı :  0.06996931814259144   Cr :  0.7
# Rastgele Sayı :  0.5286510283786761   Cr :  0.7
# ui :  [5.66343967 4.09197774]
# Birey 2: Xi = [ 1.6693909  -3.34790286], ui = [5.66343967 4.09197774],  xi Fitness= 13.9953,  ui Fitness = 48.8188
#
#
#
# İşlem yapılan birey  [2.52004709 2.15628981]
# Rastgele seçilen 3 birey : xr1 [4.16981518 2.26308158]  xr2 [-1.82163567 -0.29001804]   xr3 [ 1.6693909  -3.34790286]
# Fark Vektörü :  [1.37699392 4.70938944]
# Rastgele Sayı :  0.47372899253447576   Cr :  0.7
# Rastgele Sayı :  0.521118201054762   Cr :  0.7
# ui :  [1.37699392 4.70938944]
# Birey 3: Xi = [2.52004709 2.15628981], ui = [1.37699392 4.70938944],  xi Fitness= 11.0002,  ui Fitness = 24.0745
#
#
#
# İşlem yapılan birey  [4.16981518 2.26308158]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [2.52004709 2.15628981]   xr3 [ 1.6693909  -3.34790286]
# Fark Vektörü :  [-1.14111073  4.1133361 ]
# Rastgele Sayı :  0.9418418762336237   Cr :  0.7
# Rastgele Sayı :  0.7824898686650122   Cr :  0.7
# ui :  [4.16981518 2.26308158]
# Birey 4: Xi = [4.16981518 2.26308158], ui = [4.16981518 2.26308158],  xi Fitness= 22.5089,  ui Fitness = 22.5089
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [4.16981518 2.26308158]  xr2 [ 1.6693909  -3.34790286]   xr3 [2.52004709 2.15628981]
# Fark Vektörü :  [ 3.48929024 -2.14027256]
# Rastgele Sayı :  0.006429411235480353   Cr :  0.7
# Rastgele Sayı :  0.41245882122707234   Cr :  0.7
# ui :  [ 3.48929024 -2.14027256]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [ 3.48929024 -2.14027256],  xi Fitness= 0.0824,  ui Fitness = 16.7559
# Iteration 7
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909  -3.34790286]
#  [ 2.52004709  2.15628981]
#  [ 4.16981518  2.26308158]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [ 0.24057445 -0.15652833]  xr2 [ 1.6693909  -3.34790286]   xr3 [4.16981518 2.26308158]
# Fark Vektörü :  [-1.75976498 -4.64531589]
# Rastgele Sayı :  0.5262755981100217   Cr :  0.7
# Rastgele Sayı :  0.5790128488883615   Cr :  0.7
# ui :  [-1.75976498 -4.64531589]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [-1.75976498 -4.64531589],  xi Fitness= 3.4025,  ui Fitness = 24.6757
#
#
#
# İşlem yapılan birey  [ 1.6693909  -3.34790286]
# Rastgele seçilen 3 birey : xr1 [2.52004709 2.15628981]  xr2 [ 0.24057445 -0.15652833]   xr3 [4.16981518 2.26308158]
# Fark Vektörü :  [-0.6233455   0.22060188]
# Rastgele Sayı :  0.937149759256208   Cr :  0.7
# Rastgele Sayı :  0.6400680571063752   Cr :  0.7
# ui :  [1.6693909  0.22060188]
# Birey 2: Xi = [ 1.6693909  -3.34790286], ui = [1.6693909  0.22060188],  xi Fitness= 13.9953,  ui Fitness = 2.8355
#
#
#
# İşlem yapılan birey  [2.52004709 2.15628981]
# Rastgele seçilen 3 birey : xr1 [ 0.24057445 -0.15652833]  xr2 [-1.82163567 -0.29001804]   xr3 [ 1.6693909  -3.34790286]
# Fark Vektörü :  [-2.55224681  2.28977952]
# Rastgele Sayı :  0.7509803622871669   Cr :  0.7
# Rastgele Sayı :  0.18950171082075618   Cr :  0.7
# ui :  [2.52004709 2.28977952]
# Birey 3: Xi = [2.52004709 2.15628981], ui = [2.52004709 2.28977952],  xi Fitness= 11.0002,  ui Fitness = 11.5937
#
#
#
# İşlem yapılan birey  [4.16981518 2.26308158]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [ 0.24057445 -0.15652833]   xr3 [2.52004709 2.15628981]
# Fark Vektörü :  [-3.64521378 -2.14027256]
# Rastgele Sayı :  0.8049696801561548   Cr :  0.7
# Rastgele Sayı :  0.6274101553560097   Cr :  0.7
# ui :  [ 4.16981518 -2.14027256]
# Birey 4: Xi = [4.16981518 2.26308158], ui = [ 4.16981518 -2.14027256],  xi Fitness= 22.5089,  ui Fitness = 21.9681
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [ 1.6693909  -3.34790286]  xr2 [4.16981518 2.26308158]   xr3 [-1.82163567 -0.29001804]
# Fark Vektörü :  [ 6.46255159 -1.30542316]
# Rastgele Sayı :  0.1918265619209364   Cr :  0.7
# Rastgele Sayı :  0.7149584812200737   Cr :  0.7
# ui :  [ 6.46255159 -0.15652833]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [ 6.46255159 -0.15652833],  xi Fitness= 0.0824,  ui Fitness = 41.7891
# Iteration 8
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909   0.22060188]
#  [ 2.52004709  2.15628981]
#  [ 4.16981518 -2.14027256]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [2.52004709 2.15628981]  xr2 [1.6693909  0.22060188]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [3.66310025 2.45799398]
# Rastgele Sayı :  0.033606507887830706   Cr :  0.7
# Rastgele Sayı :  0.3781563221522839   Cr :  0.7
# ui :  [3.66310025 2.45799398]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [3.66310025 2.45799398],  xi Fitness= 3.4025,  ui Fitness = 19.4600
#
#
#
# İşlem yapılan birey  [1.6693909  0.22060188]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [2.52004709 2.15628981]   xr3 [ 4.16981518 -2.14027256]
# Fark Vektörü :  [-3.14145015  3.14723185]
# Rastgele Sayı :  0.171297091994988   Cr :  0.7
# Rastgele Sayı :  0.0687788285377039   Cr :  0.7
# ui :  [-3.14145015  3.14723185]
# Birey 2: Xi = [1.6693909  0.22060188], ui = [-3.14145015  3.14723185],  xi Fitness= 2.8355,  ui Fitness = 19.7738
#
#
#
# İşlem yapılan birey  [2.52004709 2.15628981]
# Rastgele seçilen 3 birey : xr1 [ 0.24057445 -0.15652833]  xr2 [ 4.16981518 -2.14027256]   xr3 [-1.82163567 -0.29001804]
# Fark Vektörü :  [ 5.03373514 -1.63673194]
# Rastgele Sayı :  0.1092899693569167   Cr :  0.7
# Rastgele Sayı :  0.85091701424859   Cr :  0.7
# ui :  [5.03373514 2.15628981]
# Birey 3: Xi = [2.52004709 2.15628981], ui = [5.03373514 2.15628981],  xi Fitness= 11.0002,  ui Fitness = 29.9881
#
#
#
# İşlem yapılan birey  [ 4.16981518 -2.14027256]
# Rastgele seçilen 3 birey : xr1 [ 0.24057445 -0.15652833]  xr2 [-1.82163567 -0.29001804]   xr3 [1.6693909  0.22060188]
# Fark Vektörü :  [-2.55224681 -0.56502427]
# Rastgele Sayı :  0.7101339462142398   Cr :  0.7
# Rastgele Sayı :  0.7689026721721375   Cr :  0.7
# ui :  [ 4.16981518 -2.14027256]
# Birey 4: Xi = [ 4.16981518 -2.14027256], ui = [ 4.16981518 -2.14027256],  xi Fitness= 21.9681,  ui Fitness = 21.9681
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [1.6693909  0.22060188]  xr2 [ 4.16981518 -2.14027256]   xr3 [-1.82163567 -0.29001804]
# Fark Vektörü :  [ 6.46255159 -1.25960173]
# Rastgele Sayı :  0.3991002360301401   Cr :  0.7
# Rastgele Sayı :  0.7218472381458798   Cr :  0.7
# ui :  [ 6.46255159 -0.15652833]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [ 6.46255159 -0.15652833],  xi Fitness= 0.0824,  ui Fitness = 41.7891
# Iteration 9
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909   0.22060188]
#  [ 2.52004709  2.15628981]
#  [ 4.16981518 -2.14027256]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [2.52004709 2.15628981]  xr2 [ 4.16981518 -2.14027256]   xr3 [1.6693909  0.22060188]
# Fark Vektörü :  [4.52038651 0.26759026]
# Rastgele Sayı :  0.14000922123796145   Cr :  0.7
# Rastgele Sayı :  0.17537300651332366   Cr :  0.7
# ui :  [4.52038651 0.26759026]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [4.52038651 0.26759026],  xi Fitness= 3.4025,  ui Fitness = 20.5055
#
#
#
# İşlem yapılan birey  [1.6693909  0.22060188]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [2.52004709 2.15628981]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [0.00194243 1.56023647]
# Rastgele Sayı :  0.7233912349550585   Cr :  0.7
# Rastgele Sayı :  0.30594540670168147   Cr :  0.7
# ui :  [1.6693909  1.56023647]
# Birey 2: Xi = [1.6693909  0.22060188], ui = [1.6693909  1.56023647],  xi Fitness= 2.8355,  ui Fitness = 5.2212
#
#
#
# İşlem yapılan birey  [2.52004709 2.15628981]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [ 4.16981518 -2.14027256]   xr3 [1.6693909  0.22060188]
# Fark Vektörü :  [ 0.17870375 -2.17871759]
# Rastgele Sayı :  0.2804082298651487   Cr :  0.7
# Rastgele Sayı :  0.3689692381711137   Cr :  0.7
# ui :  [ 0.17870375 -2.17871759]
# Birey 3: Xi = [2.52004709 2.15628981], ui = [ 0.17870375 -2.17871759],  xi Fitness= 11.0002,  ui Fitness = 4.7787
#
#
#
# İşlem yapılan birey  [ 4.16981518 -2.14027256]
# Rastgele seçilen 3 birey : xr1 [2.52004709 2.15628981]  xr2 [ 0.24057445 -0.15652833]   xr3 [-1.82163567 -0.29001804]
# Fark Vektörü :  [4.16981518 2.26308158]
# Rastgele Sayı :  0.5808136611430021   Cr :  0.7
# Rastgele Sayı :  0.9491869051574691   Cr :  0.7
# ui :  [ 4.16981518 -2.14027256]
# Birey 4: Xi = [ 4.16981518 -2.14027256], ui = [ 4.16981518 -2.14027256],  xi Fitness= 21.9681,  ui Fitness = 21.9681
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [ 4.16981518 -2.14027256]  xr2 [2.52004709 2.15628981]   xr3 [-1.82163567 -0.29001804]
# Fark Vektörü :  [ 7.64316139 -0.18322627]
# Rastgele Sayı :  0.12215516199848009   Cr :  0.7
# Rastgele Sayı :  0.296267351844406   Cr :  0.7
# ui :  [ 7.64316139 -0.18322627]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [ 7.64316139 -0.18322627],  xi Fitness= 0.0824,  ui Fitness = 58.4515
# Iteration 10
# Populasyon: [[-1.82163567 -0.29001804]
#  [ 1.6693909   0.22060188]
#  [ 0.17870375 -2.17871759]
#  [ 4.16981518 -2.14027256]
#  [ 0.24057445 -0.15652833]]
#
#
# İşlem yapılan birey  [-1.82163567 -0.29001804]
# Rastgele seçilen 3 birey : xr1 [ 0.24057445 -0.15652833]  xr2 [ 4.16981518 -2.14027256]   xr3 [1.6693909  0.22060188]
# Fark Vektörü :  [ 2.24091388 -2.04522788]
# Rastgele Sayı :  0.02528959028788058   Cr :  0.7
# Rastgele Sayı :  0.9590922270636015   Cr :  0.7
# ui :  [ 2.24091388 -0.29001804]
# Birey 1: Xi = [-1.82163567 -0.29001804], ui = [ 2.24091388 -0.29001804],  xi Fitness= 3.4025,  ui Fitness = 5.1058
#
#
#
# İşlem yapılan birey  [1.6693909  0.22060188]
# Rastgele seçilen 3 birey : xr1 [-1.82163567 -0.29001804]  xr2 [ 0.17870375 -2.17871759]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [-1.87113223 -1.90776945]
# Rastgele Sayı :  0.9125101880879783   Cr :  0.7
# Rastgele Sayı :  0.7743858838850586   Cr :  0.7
# ui :  [1.6693909  0.22060188]
# Birey 2: Xi = [1.6693909  0.22060188], ui = [1.6693909  0.22060188],  xi Fitness= 2.8355,  ui Fitness = 2.8355
#
#
#
# İşlem yapılan birey  [ 0.17870375 -2.17871759]
# Rastgele seçilen 3 birey : xr1 [1.6693909  0.22060188]  xr2 [-1.82163567 -0.29001804]   xr3 [ 0.24057445 -0.15652833]
# Fark Vektörü :  [0.0196228  0.11381011]
# Rastgele Sayı :  0.8306566876764656   Cr :  0.7
# Rastgele Sayı :  0.10334940687528182   Cr :  0.7
# ui :  [0.17870375 0.11381011]
# Birey 3: Xi = [ 0.17870375 -2.17871759], ui = [0.17870375 0.11381011],  xi Fitness= 4.7787,  ui Fitness = 0.0449
#
#
#
# İşlem yapılan birey  [ 4.16981518 -2.14027256]
# Rastgele seçilen 3 birey : xr1 [ 0.17870375 -2.17871759]  xr2 [ 0.24057445 -0.15652833]   xr3 [1.6693909  0.22060188]
# Fark Vektörü :  [-0.96434941 -2.48042177]
# Rastgele Sayı :  0.5956966379327562   Cr :  0.7
# Rastgele Sayı :  0.4619674404349846   Cr :  0.7
# ui :  [-0.96434941 -2.48042177]
# Birey 4: Xi = [ 4.16981518 -2.14027256], ui = [-0.96434941 -2.48042177],  xi Fitness= 21.9681,  ui Fitness = 7.0825
#
#
#
# İşlem yapılan birey  [ 0.24057445 -0.15652833]
# Rastgele seçilen 3 birey : xr1 [ 4.16981518 -2.14027256]  xr2 [ 0.17870375 -2.17871759]   xr3 [1.6693909  0.22060188]
# Fark Vektörü :  [ 2.97726547 -4.05972814]
# Rastgele Sayı :  0.9316763374817159   Cr :  0.7
# Rastgele Sayı :  0.15501915810986233   Cr :  0.7
# ui :  [ 0.24057445 -4.05972814]
# Birey 5: Xi = [ 0.24057445 -0.15652833], ui = [ 0.24057445 -4.05972814],  xi Fitness= 0.0824,  ui Fitness = 16.5393
#  En iyi çözüm: [0.17870375 0.11381011]
# En iyi fitness: 0.044887773182113885
