# %% [markdown]
# <a href="https://colab.research.google.com/github/ugurtalas/SezgiselOtimizasyonDersNotlari/blob/main/DE_x2Graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametreler
pop_size = 5      # Popülasyon boyutu
dimensions = 1    # Boyut (burada tek değişkenli)
mutation_factor = 0.8
crossover_rate = 0.7
iterations = 10   # İterasyon sayısı

# Hedef fonksiyon: x^2
def objective_function(x):
    return x[0] ** 2

# Başlangıç popülasyonu oluştur
population = np.random.uniform(-10, 10, (pop_size, dimensions))

# Her iterasyonda işlemleri ekrana yazdır ve grafiği çizdir
for i in range(iterations):
    print(f"\nIteration {i + 1}")
    new_population = np.copy(population)
    print(f"Populasyon: {new_population}")
    print("\n")

    # Bireyleri işleyin
    for j in range(pop_size):
        # Üç rastgele farklı birey seç
        indices = np.random.choice(pop_size, 3, replace=False)
        while j in indices:
            indices = np.random.choice(pop_size, 3, replace=False)
        print("İşlem yapılan birey ", population[j])
        a, b, c = population[indices]
        mutant = a + mutation_factor * (b - c)
        print("Rastgele seçilen 3 birey : ", a, b, c)
        print("Mutasyon Sonucu : ", mutant)

        trial = np.copy(population[j])
        rn = np.random.rand()
        print("Random Sayı : ", rn, "  CR : ", crossover_rate)
        if rn < crossover_rate:
            trial[0] = mutant[0]

        # Değerlendirme
        if objective_function(trial) < objective_function(population[j]):
            new_population[j] = trial
            print("Çocuk popülasyona devam ediyor")
        else:
            print("Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.")

        # Hesaplamaları yazdır
        print(f"Birey {j + 1}: Xi = {population[j][0]:.4f}, Çocuk = {trial[0]:.4f}, "
              f" Mevcut Fitness= {objective_function(population[j]):.4f}, "
              f" Çocuk Fitness = {objective_function(trial):.4f}")
        print("\n\n")

    # Popülasyonu güncelle
    population = new_population

    # Her iterasyon sonunda popülasyonu grafik üzerinde göster
    x_values = np.linspace(-10, 10, 100)
    y_values = x_values**2

    plt.figure(figsize=(8, 6))
    plt.plot(x_values, y_values, label='Objective Function (x^2)', color='orange')
    plt.scatter(population, [objective_function(x) for x in population], color='blue', label='Bireyler')
    plt.title(f'Iteration {i + 1}')
    plt.xlabel('Değer')
    plt.ylabel('Fitness (Objective Function)')
    plt.legend()
    plt.grid(True)
    plt.show()

# Sonuç
best_individual = min(population, key=objective_function)
print("\nBest solution found:", best_individual[0])
print("Objective value:", objective_function(best_individual))
# Out:
# Iteration 1
# Populasyon: [[ 4.3929461 ]
#  [ 9.51032811]
#  [ 4.72118853]
#  [-4.29086556]
#  [ 5.48656347]]
#
#
# İşlem yapılan birey  [4.3929461]
# Rastgele seçilen 3 birey :  [-4.29086556] [4.72118853] [9.51032811]
# Mutasyon Sonucu :  [-8.12217722]
# Random Sayı :  0.9567867064154664   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 4.3929, Çocuk = 4.3929,  Mevcut Fitness= 19.2980,  Çocuk Fitness = 19.2980
#
#
#
# İşlem yapılan birey  [9.51032811]
# Rastgele seçilen 3 birey :  [4.3929461] [-4.29086556] [5.48656347]
# Mutasyon Sonucu :  [-3.42899713]
# Random Sayı :  0.7914598372067793   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 9.5103, Çocuk = 9.5103,  Mevcut Fitness= 90.4463,  Çocuk Fitness = 90.4463
#
#
#
# İşlem yapılan birey  [4.72118853]
# Rastgele seçilen 3 birey :  [4.3929461] [-4.29086556] [5.48656347]
# Mutasyon Sonucu :  [-3.42899713]
# Random Sayı :  0.8577772325955455   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 3: Xi = 4.7212, Çocuk = 4.7212,  Mevcut Fitness= 22.2896,  Çocuk Fitness = 22.2896
#
#
#
# İşlem yapılan birey  [-4.29086556]
# Rastgele seçilen 3 birey :  [4.72118853] [4.3929461] [5.48656347]
# Mutasyon Sonucu :  [3.84629463]
# Random Sayı :  0.3596683562339432   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 4: Xi = -4.2909, Çocuk = 3.8463,  Mevcut Fitness= 18.4115,  Çocuk Fitness = 14.7940
#
#
#
# İşlem yapılan birey  [5.48656347]
# Rastgele seçilen 3 birey :  [4.72118853] [4.3929461] [9.51032811]
# Mutasyon Sonucu :  [0.62728292]
# Random Sayı :  0.33591572165734296   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 5: Xi = 5.4866, Çocuk = 0.6273,  Mevcut Fitness= 30.1024,  Çocuk Fitness = 0.3935
# Iteration 2
# Populasyon: [[4.3929461 ]
#  [9.51032811]
#  [4.72118853]
#  [3.84629463]
#  [0.62728292]]
#
#
# İşlem yapılan birey  [4.3929461]
# Rastgele seçilen 3 birey :  [9.51032811] [3.84629463] [4.72118853]
# Mutasyon Sonucu :  [8.81041299]
# Random Sayı :  0.7445028931049127   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 4.3929, Çocuk = 4.3929,  Mevcut Fitness= 19.2980,  Çocuk Fitness = 19.2980
#
#
#
# İşlem yapılan birey  [9.51032811]
# Rastgele seçilen 3 birey :  [3.84629463] [4.72118853] [0.62728292]
# Mutasyon Sonucu :  [7.12141912]
# Random Sayı :  0.09898973116351018   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 2: Xi = 9.5103, Çocuk = 7.1214,  Mevcut Fitness= 90.4463,  Çocuk Fitness = 50.7146
#
#
#
# İşlem yapılan birey  [4.72118853]
# Rastgele seçilen 3 birey :  [4.3929461] [0.62728292] [9.51032811]
# Mutasyon Sonucu :  [-2.71349005]
# Random Sayı :  0.624680405105877   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 3: Xi = 4.7212, Çocuk = -2.7135,  Mevcut Fitness= 22.2896,  Çocuk Fitness = 7.3630
#
#
#
# İşlem yapılan birey  [3.84629463]
# Rastgele seçilen 3 birey :  [0.62728292] [4.3929461] [4.72118853]
# Mutasyon Sonucu :  [0.36468898]
# Random Sayı :  0.9176775967025236   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 4: Xi = 3.8463, Çocuk = 3.8463,  Mevcut Fitness= 14.7940,  Çocuk Fitness = 14.7940
#
#
#
# İşlem yapılan birey  [0.62728292]
# Rastgele seçilen 3 birey :  [4.72118853] [3.84629463] [9.51032811]
# Mutasyon Sonucu :  [0.18996175]
# Random Sayı :  0.5490091296173601   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 5: Xi = 0.6273, Çocuk = 0.1900,  Mevcut Fitness= 0.3935,  Çocuk Fitness = 0.0361
# Iteration 3
# Populasyon: [[ 4.3929461 ]
#  [ 7.12141912]
#  [-2.71349005]
#  [ 3.84629463]
#  [ 0.18996175]]
#
#
# İşlem yapılan birey  [4.3929461]
# Rastgele seçilen 3 birey :  [0.18996175] [7.12141912] [-2.71349005]
# Mutasyon Sonucu :  [8.05788908]
# Random Sayı :  0.7186975235653911   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 4.3929, Çocuk = 4.3929,  Mevcut Fitness= 19.2980,  Çocuk Fitness = 19.2980
#
#
#
# İşlem yapılan birey  [7.12141912]
# Rastgele seçilen 3 birey :  [-2.71349005] [3.84629463] [0.18996175]
# Mutasyon Sonucu :  [0.21157626]
# Random Sayı :  0.5940022668886977   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 2: Xi = 7.1214, Çocuk = 0.2116,  Mevcut Fitness= 50.7146,  Çocuk Fitness = 0.0448
#
#
#
# İşlem yapılan birey  [-2.71349005]
# Rastgele seçilen 3 birey :  [7.12141912] [0.18996175] [4.3929461]
# Mutasyon Sonucu :  [3.75903164]
# Random Sayı :  0.9476351788854451   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 3: Xi = -2.7135, Çocuk = -2.7135,  Mevcut Fitness= 7.3630,  Çocuk Fitness = 7.3630
#
#
#
# İşlem yapılan birey  [3.84629463]
# Rastgele seçilen 3 birey :  [4.3929461] [7.12141912] [-2.71349005]
# Mutasyon Sonucu :  [12.26087343]
# Random Sayı :  0.04259598468505854   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 4: Xi = 3.8463, Çocuk = 12.2609,  Mevcut Fitness= 14.7940,  Çocuk Fitness = 150.3290
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [4.3929461] [7.12141912] [-2.71349005]
# Mutasyon Sonucu :  [12.26087343]
# Random Sayı :  0.6244029324559349   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = 12.2609,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 150.3290
# Iteration 4
# Populasyon: [[ 4.3929461 ]
#  [ 0.21157626]
#  [-2.71349005]
#  [ 3.84629463]
#  [ 0.18996175]]
#
#
# İşlem yapılan birey  [4.3929461]
# Rastgele seçilen 3 birey :  [-2.71349005] [0.21157626] [0.18996175]
# Mutasyon Sonucu :  [-2.69619844]
# Random Sayı :  0.9074431238907996   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 4.3929, Çocuk = 4.3929,  Mevcut Fitness= 19.2980,  Çocuk Fitness = 19.2980
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [3.84629463] [4.3929461] [-2.71349005]
# Mutasyon Sonucu :  [9.53144355]
# Random Sayı :  0.44141929414392245   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 0.2116, Çocuk = 9.5314,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 90.8484
#
#
#
# İşlem yapılan birey  [-2.71349005]
# Rastgele seçilen 3 birey :  [4.3929461] [3.84629463] [0.21157626]
# Mutasyon Sonucu :  [7.3007208]
# Random Sayı :  0.6314408177442871   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 3: Xi = -2.7135, Çocuk = 7.3007,  Mevcut Fitness= 7.3630,  Çocuk Fitness = 53.3005
#
#
#
# İşlem yapılan birey  [3.84629463]
# Rastgele seçilen 3 birey :  [0.21157626] [0.18996175] [-2.71349005]
# Mutasyon Sonucu :  [2.5343377]
# Random Sayı :  0.056284790663146955   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 4: Xi = 3.8463, Çocuk = 2.5343,  Mevcut Fitness= 14.7940,  Çocuk Fitness = 6.4229
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [0.21157626] [3.84629463] [-2.71349005]
# Mutasyon Sonucu :  [5.459404]
# Random Sayı :  0.5563804090245489   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = 5.4594,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 29.8051
# Iteration 5
# Populasyon: [[ 4.3929461 ]
#  [ 0.21157626]
#  [-2.71349005]
#  [ 2.5343377 ]
#  [ 0.18996175]]
#
#
# İşlem yapılan birey  [4.3929461]
# Rastgele seçilen 3 birey :  [2.5343377] [0.21157626] [0.18996175]
# Mutasyon Sonucu :  [2.5516293]
# Random Sayı :  0.9176745014469541   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 4.3929, Çocuk = 4.3929,  Mevcut Fitness= 19.2980,  Çocuk Fitness = 19.2980
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [-2.71349005] [4.3929461] [2.5343377]
# Mutasyon Sonucu :  [-1.22660333]
# Random Sayı :  0.5417128729119634   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 0.2116, Çocuk = -1.2266,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 1.5046
#
#
#
# İşlem yapılan birey  [-2.71349005]
# Rastgele seçilen 3 birey :  [0.21157626] [2.5343377] [0.18996175]
# Mutasyon Sonucu :  [2.08707701]
# Random Sayı :  0.6305738901370623   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 3: Xi = -2.7135, Çocuk = 2.0871,  Mevcut Fitness= 7.3630,  Çocuk Fitness = 4.3559
#
#
#
# İşlem yapılan birey  [2.5343377]
# Rastgele seçilen 3 birey :  [-2.71349005] [0.18996175] [4.3929461]
# Mutasyon Sonucu :  [-6.07587753]
# Random Sayı :  0.37066069554653214   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 4: Xi = 2.5343, Çocuk = -6.0759,  Mevcut Fitness= 6.4229,  Çocuk Fitness = 36.9163
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [-2.71349005] [4.3929461] [0.21157626]
# Mutasyon Sonucu :  [0.63160582]
# Random Sayı :  0.6441325057592273   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = 0.6316,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 0.3989
# Iteration 6
# Populasyon: [[4.3929461 ]
#  [0.21157626]
#  [2.08707701]
#  [2.5343377 ]
#  [0.18996175]]
#
#
# İşlem yapılan birey  [4.3929461]
# Rastgele seçilen 3 birey :  [2.08707701] [2.5343377] [0.21157626]
# Mutasyon Sonucu :  [3.94528617]
# Random Sayı :  0.14705254398982925   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 1: Xi = 4.3929, Çocuk = 3.9453,  Mevcut Fitness= 19.2980,  Çocuk Fitness = 15.5653
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [4.3929461] [2.08707701] [2.5343377]
# Mutasyon Sonucu :  [4.03513755]
# Random Sayı :  0.5405398920146398   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 0.2116, Çocuk = 4.0351,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 16.2823
#
#
#
# İşlem yapılan birey  [2.08707701]
# Rastgele seçilen 3 birey :  [4.3929461] [0.18996175] [2.5343377]
# Mutasyon Sonucu :  [2.51744534]
# Random Sayı :  0.04477831511036334   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 3: Xi = 2.0871, Çocuk = 2.5174,  Mevcut Fitness= 4.3559,  Çocuk Fitness = 6.3375
#
#
#
# İşlem yapılan birey  [2.5343377]
# Rastgele seçilen 3 birey :  [0.18996175] [2.08707701] [0.21157626]
# Mutasyon Sonucu :  [1.69036235]
# Random Sayı :  0.633830327997736   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 4: Xi = 2.5343, Çocuk = 1.6904,  Mevcut Fitness= 6.4229,  Çocuk Fitness = 2.8573
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [0.21157626] [4.3929461] [2.5343377]
# Mutasyon Sonucu :  [1.69846298]
# Random Sayı :  0.5389726348211861   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = 1.6985,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 2.8848
# Iteration 7
# Populasyon: [[3.94528617]
#  [0.21157626]
#  [2.08707701]
#  [1.69036235]
#  [0.18996175]]
#
#
# İşlem yapılan birey  [3.94528617]
# Rastgele seçilen 3 birey :  [1.69036235] [0.21157626] [2.08707701]
# Mutasyon Sonucu :  [0.18996175]
# Random Sayı :  0.29773778586097444   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 1: Xi = 3.9453, Çocuk = 0.1900,  Mevcut Fitness= 15.5653,  Çocuk Fitness = 0.0361
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [3.94528617] [1.69036235] [0.18996175]
# Mutasyon Sonucu :  [5.14560665]
# Random Sayı :  0.5438480718495972   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 0.2116, Çocuk = 5.1456,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 26.4773
#
#
#
# İşlem yapılan birey  [2.08707701]
# Rastgele seçilen 3 birey :  [3.94528617] [1.69036235] [0.21157626]
# Mutasyon Sonucu :  [5.12831504]
# Random Sayı :  0.45390154041081   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 3: Xi = 2.0871, Çocuk = 5.1283,  Mevcut Fitness= 4.3559,  Çocuk Fitness = 26.2996
#
#
#
# İşlem yapılan birey  [1.69036235]
# Rastgele seçilen 3 birey :  [2.08707701] [3.94528617] [0.18996175]
# Mutasyon Sonucu :  [5.09133655]
# Random Sayı :  0.8258151702319152   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 4: Xi = 1.6904, Çocuk = 1.6904,  Mevcut Fitness= 2.8573,  Çocuk Fitness = 2.8573
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [0.21157626] [1.69036235] [3.94528617]
# Mutasyon Sonucu :  [-1.59236279]
# Random Sayı :  0.10025951886669282   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = -1.5924,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 2.5356
# Iteration 8
# Populasyon: [[0.18996175]
#  [0.21157626]
#  [2.08707701]
#  [1.69036235]
#  [0.18996175]]
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [0.21157626] [2.08707701] [1.69036235]
# Mutasyon Sonucu :  [0.52894798]
# Random Sayı :  0.8405157944734437   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 0.1900, Çocuk = 0.1900,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 0.0361
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [0.18996175] [1.69036235] [0.18996175]
# Mutasyon Sonucu :  [1.39028223]
# Random Sayı :  0.511911323600237   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 0.2116, Çocuk = 1.3903,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 1.9329
#
#
#
# İşlem yapılan birey  [2.08707701]
# Rastgele seçilen 3 birey :  [1.69036235] [0.18996175] [0.18996175]
# Mutasyon Sonucu :  [1.69036235]
# Random Sayı :  0.09427403208772678   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 3: Xi = 2.0871, Çocuk = 1.6904,  Mevcut Fitness= 4.3559,  Çocuk Fitness = 2.8573
#
#
#
# İşlem yapılan birey  [1.69036235]
# Rastgele seçilen 3 birey :  [0.21157626] [0.18996175] [0.18996175]
# Mutasyon Sonucu :  [0.21157626]
# Random Sayı :  0.5647320062740174   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 4: Xi = 1.6904, Çocuk = 0.2116,  Mevcut Fitness= 2.8573,  Çocuk Fitness = 0.0448
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [1.69036235] [0.21157626] [0.18996175]
# Mutasyon Sonucu :  [1.70765396]
# Random Sayı :  0.7471861295461075   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = 0.1900,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 0.0361
# Iteration 9
# Populasyon: [[0.18996175]
#  [0.21157626]
#  [1.69036235]
#  [0.21157626]
#  [0.18996175]]
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [1.69036235] [0.21157626] [0.21157626]
# Mutasyon Sonucu :  [1.69036235]
# Random Sayı :  0.8982629485191365   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 0.1900, Çocuk = 0.1900,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 0.0361
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [1.69036235] [0.18996175] [0.21157626]
# Mutasyon Sonucu :  [1.67307075]
# Random Sayı :  0.29747481212069715   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 0.2116, Çocuk = 1.6731,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 2.7992
#
#
#
# İşlem yapılan birey  [1.69036235]
# Rastgele seçilen 3 birey :  [0.21157626] [0.21157626] [0.18996175]
# Mutasyon Sonucu :  [0.22886786]
# Random Sayı :  0.12811122747748704   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 3: Xi = 1.6904, Çocuk = 0.2289,  Mevcut Fitness= 2.8573,  Çocuk Fitness = 0.0524
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [0.18996175] [0.18996175] [0.21157626]
# Mutasyon Sonucu :  [0.17267014]
# Random Sayı :  0.10331863410645936   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 4: Xi = 0.2116, Çocuk = 0.1727,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 0.0298
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [0.21157626] [0.21157626] [1.69036235]
# Mutasyon Sonucu :  [-0.97145262]
# Random Sayı :  0.6029849439735988   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = -0.9715,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 0.9437
# Iteration 10
# Populasyon: [[0.18996175]
#  [0.21157626]
#  [0.22886786]
#  [0.17267014]
#  [0.18996175]]
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [0.21157626] [0.18996175] [0.22886786]
# Mutasyon Sonucu :  [0.18045136]
# Random Sayı :  0.9951349444150895   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 1: Xi = 0.1900, Çocuk = 0.1900,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 0.0361
#
#
#
# İşlem yapılan birey  [0.21157626]
# Rastgele seçilen 3 birey :  [0.18996175] [0.22886786] [0.18996175]
# Mutasyon Sonucu :  [0.22108664]
# Random Sayı :  0.5590866848740897   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 2: Xi = 0.2116, Çocuk = 0.2211,  Mevcut Fitness= 0.0448,  Çocuk Fitness = 0.0489
#
#
#
# İşlem yapılan birey  [0.22886786]
# Rastgele seçilen 3 birey :  [0.17267014] [0.21157626] [0.18996175]
# Mutasyon Sonucu :  [0.18996175]
# Random Sayı :  0.2547610411268614   CR :  0.7
# Çocuk popülasyona devam ediyor
# Birey 3: Xi = 0.2289, Çocuk = 0.1900,  Mevcut Fitness= 0.0524,  Çocuk Fitness = 0.0361
#
#
#
# İşlem yapılan birey  [0.17267014]
# Rastgele seçilen 3 birey :  [0.22886786] [0.21157626] [0.18996175]
# Mutasyon Sonucu :  [0.24615947]
# Random Sayı :  0.3557061356324519   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 4: Xi = 0.1727, Çocuk = 0.2462,  Mevcut Fitness= 0.0298,  Çocuk Fitness = 0.0606
#
#
#
# İşlem yapılan birey  [0.18996175]
# Rastgele seçilen 3 birey :  [0.17267014] [0.22886786] [0.18996175]
# Mutasyon Sonucu :  [0.20379503]
# Random Sayı :  0.04897727503594129   CR :  0.7
# Kendi fitness'ı daha iyi olduğu için kendisi devam ediyor.
# Birey 5: Xi = 0.1900, Çocuk = 0.2038,  Mevcut Fitness= 0.0361,  Çocuk Fitness = 0.0415
# Best solution found: 0.17267014058815758
# Objective value: 0.029814977450734102
